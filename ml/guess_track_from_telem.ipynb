# %% [markdown]
# # Purpose
#
# Throughout a race the speed of an F1 car changes dramatically.  Maximized at the end of a straight before hard braking zones, with smooth acceleration out of each corner.  The speed v.s. time curve is the most iconic piece of telemetry used for interpreting a driver's lap quality.  Because each track has a distinct shape and unique combination of straights and corners, each telemetry trace tells a story of the circuit it belongs to; the signature of a track.
#
# In this notebook I demonstrate the ability to identify the circuit in question solely based off of this speed telemetry trace using a *Supervised Neural Network* trained a subset of laps obtained from the F1 2022 season using the [fastf1](https://theoehrly.github.io/Fast-F1) package.
#
# # Method
#
# Telemetry traces are obtained for each track using the [fastf1](https://theoehrly.github.io/Fast-F1) package.  This tool does not provide data sampled at a regular rate, so some data cleaning is required for their use in this notebook.  This has been performed in advance using the functions provided by the [f1_djsouthall/tools/fastf1_tools.py](https://github.com/djsouthall/f1_djsouthall/blob/main/tools/fastf1_tools.py) script.  These laps are resampled to 0.1 second sampling, and all non-standard laps have been removed (i.e. laps with a safety car, yellow flags, pitstop in-lap, pitstop out-lap).  These standardized laps are loaded here and used for training the NN.
#
# I am using the [tensorflow](https://www.tensorflow.org/) and [keras](https://keras.io/) APIs to construct and train this model.

# %%
# Perform imports and setup code

disable_gpu = False # Helpful for debugging, sometimes performs differently with GPU enabled. 

# OS imports
import os
import sys

# Common imports
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib import cm
# %matplotlib widget
plt.ion()

# F1 imports
import fastf1
import fastf1.plotting
fastf1.Cache.enable_cache(os.environ['f1_cache'])  
sys.path.append(os.environ['f1_install'])
from tools.fastf1_tools import loadTelemForYear, loadTelemForEvent

# ML imports
import tensorflow as tf

if disable_gpu:
    try:
        # Disable all GPUS
        tf.config.set_visible_devices([], 'GPU')
        visible_devices = tf.config.get_visible_devices()
        for device in visible_devices:
            assert device.device_type != 'GPU'
    except:
        # Invalid device or cannot modify virtual devices once initialized.
        pass
    tf.config.set_visible_devices([], 'GPU')
    os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

from tensorflow import keras
import keras_tuner
from keras import optimizers

# Check for GPU
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print('Number of GPUs Available: {}'.format(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# Disable warnings
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# Number of GPUs Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Next we load in the lap telemetry and filter it down to the subset of drivers and tracks we wish to train on.

# %%
# Load and filter lap telemetry.

# Specify lap telemetry info
path = os.path.join(os.environ['f1_install'], 'dataframes') # Location of pre-processed telemetry data.
year = 2022
telem_param = 'Speed'

# Get telem for entire year
refined_laps, track_index_key = loadTelemForYear(year, path=os.path.join(os.environ['f1_install'], 'dataframes'), telem_param=telem_param, return_index_key=True) # Formatted laps generated by ml/save_lap_telemetry.py

# Here we can filter to a subset of drivers
all_drivers = np.unique([c.split('_')[0] for c in refined_laps.columns])

# For simplificity here we only consider the laps of Max Verstappen, 
# however in principle we could train the NN to distinguish using all 
# driver data.
if True:
    choose_drivers = ['VER']
else:
    choose_drivers = all_drivers

# Here we have the option to only include a subset of the tracks.
# We will use all of them.
all_track_indices = list(track_index_key.keys())

if True:
    included_track_indices = all_track_indices # Use all of the tracks
else:
    included_track_indices = all_track_indices[:5] # Use only the first 5 tracks

columns = refined_laps.columns[[np.isin(c.split('_')[0], choose_drivers) for c in refined_laps.columns]] # Select subset of columns relevant to selected drivers
columns = columns[[np.isin(int(c.split('_')[1]), included_track_indices) for c in columns]] # Select subset of columns relevant to selected tracks
refined_laps = refined_laps[columns] # Reduce to only relevant columns (laps)
# Out:
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Bahrain_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Saudi_Arabian_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Australian_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Emilia_Romagna_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Miami_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Spanish_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Monaco_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Azerbaijan_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Canadian_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_British_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Austrian_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_French_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Hungarian_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Belgian_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Dutch_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Italian_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Singapore_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Japanese_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_United_States_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Mexico_City_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_São_Paulo_Grand_Prix_2022.pkl
# Loading C:\Users\dsouthall\projects\f1\f1_djsouthall\dataframes\Speed_Abu_Dhabi_Grand_Prix_2022.pkl

# %% [markdown]
# Here we randomize the lap order.  Though keras shuffles these as well, I choose to do so in advance here for clarity.
#
# At this stage I also clip the laps to the shortest lap of the year to remove NaN values where lap lengths differ.

# %%
randomized_indices = np.random.choice(range(len(refined_laps.columns)), len(refined_laps.columns))
refined_laps = refined_laps.iloc[:, randomized_indices]# Shuffled randomly
refined_laps = refined_laps.dropna() # Will cut off laps beyond shortest lap of the season.  Quick and dirty way to normalize data. 

print('Column label format: {DRIVER}_{EVENT_ID}_{LAP_ID}')
print(refined_laps.head().T.head(4).T) #Print the head of the first 4 laps
# Out:
# Column label format: {DRIVER}_{EVENT_ID}_{LAP_ID}
#                          VER_12_51    VER_15_8     VER_9_2   VER_12_27
# 0 days 00:00:00         273.000000  223.000000  322.666667  273.000000
# 0 days 00:00:00.100000  276.375000  225.625000  322.375000  274.000000
# 0 days 00:00:00.200000  278.365385  227.442308  322.038462  275.153846
# 0 days 00:00:00.300000  280.143750  229.168750  321.675000  276.400000
# 0 days 00:00:00.400000  282.055785  231.733471  321.446281  276.801653

# %% [markdown]
# At this point we have obtained a set of consistently formatted (sampled equally in time and of equal length) speed traces.

# %% [markdown]
# # Sort Data
# Here we split the data into training and testing data.  We then process the labels with a vectorizer and prepare the datasets as tensors.

# %%
# Get numpy array where each row is lap, and obtain labels. 
np_laps = refined_laps.to_numpy().T #Will cut off laps longer than shortest lap in the calander.
print(np_laps.shape)

labels = np.asarray([track_index_key[int(c.split('_')[1])]['name'] for c in refined_laps.columns])

training_percent = 0.8

training_n = int(training_percent*len(refined_laps.columns))
training_indices = np.random.choice(range(len(refined_laps.columns)), size=training_n, replace=False)

testing_indices = np.arange(len(refined_laps.columns))[~np.isin(np.arange(len(refined_laps.columns)), training_indices)]

print('Training on {} laps, and testing on {}'.format(len(training_indices), len(testing_indices)))
# Out:
# (1007, 673)
# Training on 805 laps, and testing on 202

# %%
# Prepare preprocessing
scaler = keras.layers.Rescaling(scale=1.0/np.nanmax(np_laps))
vectorizer = keras.layers.TextVectorization(output_mode="int")
vectorizer.adapt(np.unique(labels))
num_classes = len(np.unique(labels))

# Prepare Training Data
training_labels = vectorizer(labels[training_indices]) - 2 # [2:] strips off the '' and 'UNK' default 0 and 1 values from vectorizer. - 2 accounts for shifting these such that labels start at 0.
training_data = scaler(np_laps[training_indices])

# Preparing Testing Data
testing_labels = vectorizer(labels[testing_indices]) - 2 # [2:] strips off the '' and 'UNK' default 0 and 1 values from vectorizer. - 2 accounts for shifting these such that labels start at 0.
testing_data = scaler(np_laps[testing_indices])

# For later human comprehension it is helpful to have a list of
# formatted GP names for each vectorized label number.  
formatted_name_dict = dict([(item['name'].replace('_','') , item['EventName'].replace('_','')) for key, item in track_index_key.items()])
label_dict = dict([(vectorizer(l).numpy()[0] - 2, formatted_name_dict[l]) for l in vectorizer.get_vocabulary()[2:]]) # [2:] strips off the '' and 'UNK' default 0 and 1 values from vectorizer. - 2 accounts for shifting these such that labels start at 0.

# These events are NOT necessarily in the same order as they are in the
# season or as they are loaded in and defined in track_index_key.
print(label_dict)
# Out:
# {0: 'United States Grand Prix', 1: 'São Paulo Grand Prix', 2: 'Spanish Grand Prix', 3: 'Singapore Grand Prix', 4: 'Saudi Arabian Grand Prix', 5: 'Monaco Grand Prix', 6: 'Miami Grand Prix', 7: 'Mexico City Grand Prix', 8: 'Japanese Grand Prix', 9: 'Italian Grand Prix', 10: 'Hungarian Grand Prix', 11: 'French Grand Prix', 12: 'Emilia Romagna Grand Prix', 13: 'Dutch Grand Prix', 14: 'Canadian Grand Prix', 15: 'British Grand Prix', 16: 'Belgian Grand Prix', 17: 'Bahrain Grand Prix', 18: 'Azerbaijan Grand Prix', 19: 'Austrian Grand Prix', 20: 'Australian Grand Prix', 21: 'Abu Dhabi Grand Prix'}

# %% [markdown]
# ## Preparing Model
# Now we start preparing the model.  Here I use a relatively simple sequentual model filled with dense layers.

# %%
convolutional = False # Still working on CNN, only NN tested right now.  

if convolutional == False:
    model = keras.models.Sequential([
        keras.layers.Dense(units=50, activation='tanh', input_shape=(training_data.shape[1],)),
        keras.layers.Dense(units=32, activation='tanh'),
        keras.layers.Dense(units=16, activation='tanh'),
        keras.layers.Dense(units=len(label_dict), activation='softmax')
        ])
else:
    model = keras.models.Sequential([
        keras.layers.Conv1D(filters=32, kernel_size=20, activation='relu', padding='same', input_shape=(training_data.shape[1],1,)),
        keras.layers.Dense(units=32, activation='tanh'),
        keras.layers.Dense(units=40, activation='tanh'),
        keras.layers.Dense(units=len(label_dict), activation='softmax')
        ])

# optimizer = optimizers.Adam(clipvalue=0.5)
optimizer = keras.optimizers.Adam(learning_rate=1e-5)#RMSprop
model.summary()

# Using accuracy as the metric below seems important. I originally was using categorical accuracy and it was causing
# problems that I could not quite understand.  Accuracy works well though. 
model.compile(optimizer=optimizer,loss="sparse_categorical_crossentropy",metrics=['accuracy'])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 50)                33700
#
#  dense_13 (Dense)            (None, 32)                1632
#
#  dense_14 (Dense)            (None, 16)                528
#
#  dense_15 (Dense)            (None, 22)                374
#
# =================================================================
# Total params: 36,234
# Trainable params: 36,234
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training Model

# %%
# Perform checks on data
assert np.any(np.isnan(training_data)) == False
assert np.any(np.isnan(training_labels)) == False
assert np.any(np.isnan(testing_data)) == False
assert np.any(np.isnan(testing_labels)) == False
assert type(training_data) == type(training_labels)

print('Training on {} laps, and testing on {}, attempting to distinguish between {} tracks.'.format(training_data.shape[0], testing_data.shape[0], len(np.unique(training_labels))))
model.fit(training_data, training_labels, batch_size=20, epochs=1000, verbose=2)#, validation_split=0.2
# Out:
# Training on 805 laps, and testing on 202, attempting to distinguish between 22 tracks.
# Epoch 1/1000
# 41/41 - 1s - loss: 3.0709 - accuracy: 0.0634 - 723ms/epoch - 18ms/step
# Epoch 2/1000
# 41/41 - 0s - loss: 3.0356 - accuracy: 0.0559 - 265ms/epoch - 6ms/step
# Epoch 3/1000
# 41/41 - 0s - loss: 3.0070 - accuracy: 0.0733 - 173ms/epoch - 4ms/step
# Epoch 4/1000
# 41/41 - 0s - loss: 2.9815 - accuracy: 0.0957 - 168ms/epoch - 4ms/step
# Epoch 5/1000
# 41/41 - 0s - loss: 2.9581 - accuracy: 0.0944 - 171ms/epoch - 4ms/step
# Epoch 6/1000
# 41/41 - 0s - loss: 2.9346 - accuracy: 0.1342 - 168ms/epoch - 4ms/step
# Epoch 7/1000
# 41/41 - 0s - loss: 2.9120 - accuracy: 0.1528 - 158ms/epoch - 4ms/step
# Epoch 8/1000
# 41/41 - 0s - loss: 2.8890 - accuracy: 0.1416 - 176ms/epoch - 4ms/step
# Epoch 9/1000
# 41/41 - 0s - loss: 2.8664 - accuracy: 0.1317 - 181ms/epoch - 4ms/step
# Epoch 10/1000
# 41/41 - 0s - loss: 2.8439 - accuracy: 0.1727 - 208ms/epoch - 5ms/step
# Epoch 11/1000
# 41/41 - 0s - loss: 2.8228 - accuracy: 0.2323 - 176ms/epoch - 4ms/step
# Epoch 12/1000
# 41/41 - 0s - loss: 2.8018 - accuracy: 0.2981 - 179ms/epoch - 4ms/step
# Epoch 13/1000
# 41/41 - 0s - loss: 2.7813 - accuracy: 0.3081 - 191ms/epoch - 5ms/step
# Epoch 14/1000
# 41/41 - 0s - loss: 2.7622 - accuracy: 0.3006 - 207ms/epoch - 5ms/step
# Epoch 15/1000
# 41/41 - 0s - loss: 2.7426 - accuracy: 0.3230 - 222ms/epoch - 5ms/step
# Epoch 16/1000
# 41/41 - 0s - loss: 2.7237 - accuracy: 0.3702 - 201ms/epoch - 5ms/step
# Epoch 17/1000
# 41/41 - 0s - loss: 2.7060 - accuracy: 0.4025 - 218ms/epoch - 5ms/step
# Epoch 18/1000
# 41/41 - 0s - loss: 2.6878 - accuracy: 0.4658 - 229ms/epoch - 6ms/step
# Epoch 19/1000
# 41/41 - 0s - loss: 2.6701 - accuracy: 0.4944 - 214ms/epoch - 5ms/step
# Epoch 20/1000
# 41/41 - 0s - loss: 2.6535 - accuracy: 0.5118 - 222ms/epoch - 5ms/step
# Epoch 21/1000
# 41/41 - 0s - loss: 2.6369 - accuracy: 0.5168 - 222ms/epoch - 5ms/step
# Epoch 22/1000
# 41/41 - 0s - loss: 2.6200 - accuracy: 0.5168 - 200ms/epoch - 5ms/step
# Epoch 23/1000
# 41/41 - 0s - loss: 2.6039 - accuracy: 0.5379 - 202ms/epoch - 5ms/step
# Epoch 24/1000
# 41/41 - 0s - loss: 2.5882 - accuracy: 0.5652 - 224ms/epoch - 5ms/step
# Epoch 25/1000
# 41/41 - 0s - loss: 2.5726 - accuracy: 0.5652 - 209ms/epoch - 5ms/step
# Epoch 26/1000
# 41/41 - 0s - loss: 2.5582 - accuracy: 0.5826 - 228ms/epoch - 6ms/step
# Epoch 27/1000
# 41/41 - 0s - loss: 2.5432 - accuracy: 0.6075 - 223ms/epoch - 5ms/step
# Epoch 28/1000
# 41/41 - 0s - loss: 2.5287 - accuracy: 0.6137 - 189ms/epoch - 5ms/step
# Epoch 29/1000
# 41/41 - 0s - loss: 2.5142 - accuracy: 0.6236 - 185ms/epoch - 5ms/step
# Epoch 30/1000
# 41/41 - 0s - loss: 2.5005 - accuracy: 0.6161 - 179ms/epoch - 4ms/step
# Epoch 31/1000
# 41/41 - 0s - loss: 2.4867 - accuracy: 0.6609 - 192ms/epoch - 5ms/step
# Epoch 32/1000
# 41/41 - 0s - loss: 2.4736 - accuracy: 0.6733 - 190ms/epoch - 5ms/step
# Epoch 33/1000
# 41/41 - 0s - loss: 2.4606 - accuracy: 0.7031 - 172ms/epoch - 4ms/step
# Epoch 34/1000
# 41/41 - 0s - loss: 2.4478 - accuracy: 0.7168 - 184ms/epoch - 4ms/step
# Epoch 35/1000
# 41/41 - 0s - loss: 2.4348 - accuracy: 0.7155 - 183ms/epoch - 4ms/step
# Epoch 36/1000
# 41/41 - 0s - loss: 2.4225 - accuracy: 0.7205 - 204ms/epoch - 5ms/step
# Epoch 37/1000
# 41/41 - 0s - loss: 2.4102 - accuracy: 0.7205 - 197ms/epoch - 5ms/step
# Epoch 38/1000
# 41/41 - 0s - loss: 2.3992 - accuracy: 0.7280 - 269ms/epoch - 7ms/step
# Epoch 39/1000
# 41/41 - 0s - loss: 2.3863 - accuracy: 0.7404 - 171ms/epoch - 4ms/step
# Epoch 40/1000
# 41/41 - 0s - loss: 2.3742 - accuracy: 0.7491 - 177ms/epoch - 4ms/step
# Epoch 41/1000
# 41/41 - 0s - loss: 2.3624 - accuracy: 0.7491 - 174ms/epoch - 4ms/step
# Epoch 42/1000
# 41/41 - 0s - loss: 2.3507 - accuracy: 0.7540 - 168ms/epoch - 4ms/step
# Epoch 43/1000
# 41/41 - 0s - loss: 2.3395 - accuracy: 0.7640 - 162ms/epoch - 4ms/step
# Epoch 44/1000
# 41/41 - 0s - loss: 2.3285 - accuracy: 0.7801 - 173ms/epoch - 4ms/step
# Epoch 45/1000
# 41/41 - 0s - loss: 2.3174 - accuracy: 0.7739 - 169ms/epoch - 4ms/step
# Epoch 46/1000
# 41/41 - 0s - loss: 2.3066 - accuracy: 0.7776 - 154ms/epoch - 4ms/step
# Epoch 47/1000
# 41/41 - 0s - loss: 2.2953 - accuracy: 0.7814 - 173ms/epoch - 4ms/step
# Epoch 48/1000
# 41/41 - 0s - loss: 2.2845 - accuracy: 0.7826 - 166ms/epoch - 4ms/step
# Epoch 49/1000
# 41/41 - 0s - loss: 2.2739 - accuracy: 0.7863 - 187ms/epoch - 5ms/step
# Epoch 50/1000
# 41/41 - 0s - loss: 2.2635 - accuracy: 0.7963 - 194ms/epoch - 5ms/step
# Epoch 51/1000
# 41/41 - 0s - loss: 2.2529 - accuracy: 0.8025 - 194ms/epoch - 5ms/step
# Epoch 52/1000
# 41/41 - 0s - loss: 2.2423 - accuracy: 0.8025 - 200ms/epoch - 5ms/step
# Epoch 53/1000
# 41/41 - 0s - loss: 2.2323 - accuracy: 0.8037 - 210ms/epoch - 5ms/step
# Epoch 54/1000
# 41/41 - 0s - loss: 2.2219 - accuracy: 0.8050 - 203ms/epoch - 5ms/step
# Epoch 55/1000
# 41/41 - 0s - loss: 2.2121 - accuracy: 0.8075 - 194ms/epoch - 5ms/step
# Epoch 56/1000
# 41/41 - 0s - loss: 2.2025 - accuracy: 0.8062 - 202ms/epoch - 5ms/step
# Epoch 57/1000
# 41/41 - 0s - loss: 2.1922 - accuracy: 0.8224 - 208ms/epoch - 5ms/step
# Epoch 58/1000
# 41/41 - 0s - loss: 2.1822 - accuracy: 0.8211 - 209ms/epoch - 5ms/step
# Epoch 59/1000
# 41/41 - 0s - loss: 2.1725 - accuracy: 0.8186 - 209ms/epoch - 5ms/step
# Epoch 60/1000
# 41/41 - 0s - loss: 2.1633 - accuracy: 0.8422 - 233ms/epoch - 6ms/step
# Epoch 61/1000
# 41/41 - 0s - loss: 2.1533 - accuracy: 0.8335 - 219ms/epoch - 5ms/step
# Epoch 62/1000
# 41/41 - 0s - loss: 2.1438 - accuracy: 0.8398 - 212ms/epoch - 5ms/step
# Epoch 63/1000
# 41/41 - 0s - loss: 2.1345 - accuracy: 0.8484 - 217ms/epoch - 5ms/step
# Epoch 64/1000
# 41/41 - 0s - loss: 2.1253 - accuracy: 0.8609 - 215ms/epoch - 5ms/step
# Epoch 65/1000
# 41/41 - 0s - loss: 2.1160 - accuracy: 0.8559 - 211ms/epoch - 5ms/step
# Epoch 66/1000
# 41/41 - 0s - loss: 2.1067 - accuracy: 0.8584 - 201ms/epoch - 5ms/step
# Epoch 67/1000
# 41/41 - 0s - loss: 2.0980 - accuracy: 0.8609 - 219ms/epoch - 5ms/step
# Epoch 68/1000
# 41/41 - 0s - loss: 2.0886 - accuracy: 0.8621 - 216ms/epoch - 5ms/step
# Epoch 69/1000
# 41/41 - 0s - loss: 2.0795 - accuracy: 0.8621 - 205ms/epoch - 5ms/step
# Epoch 70/1000
# 41/41 - 0s - loss: 2.0708 - accuracy: 0.8621 - 224ms/epoch - 5ms/step
# Epoch 71/1000
# 41/41 - 0s - loss: 2.0620 - accuracy: 0.8621 - 211ms/epoch - 5ms/step
# Epoch 72/1000
# 41/41 - 0s - loss: 2.0532 - accuracy: 0.8621 - 215ms/epoch - 5ms/step
# Epoch 73/1000
# 41/41 - 0s - loss: 2.0443 - accuracy: 0.8634 - 214ms/epoch - 5ms/step
# Epoch 74/1000
# 41/41 - 0s - loss: 2.0358 - accuracy: 0.8708 - 210ms/epoch - 5ms/step
# Epoch 75/1000
# 41/41 - 0s - loss: 2.0272 - accuracy: 0.8708 - 211ms/epoch - 5ms/step
# Epoch 76/1000
# 41/41 - 0s - loss: 2.0187 - accuracy: 0.8720 - 207ms/epoch - 5ms/step
# Epoch 77/1000
# 41/41 - 0s - loss: 2.0102 - accuracy: 0.8733 - 210ms/epoch - 5ms/step
# Epoch 78/1000
# 41/41 - 0s - loss: 2.0017 - accuracy: 0.8720 - 234ms/epoch - 6ms/step
# Epoch 79/1000
# 41/41 - 0s - loss: 1.9936 - accuracy: 0.8758 - 228ms/epoch - 6ms/step
# Epoch 80/1000
# 41/41 - 0s - loss: 1.9854 - accuracy: 0.8733 - 238ms/epoch - 6ms/step
# Epoch 81/1000
# 41/41 - 0s - loss: 1.9771 - accuracy: 0.8745 - 215ms/epoch - 5ms/step
# Epoch 82/1000
# 41/41 - 0s - loss: 1.9690 - accuracy: 0.8770 - 223ms/epoch - 5ms/step
# Epoch 83/1000
# 41/41 - 0s - loss: 1.9607 - accuracy: 0.8770 - 208ms/epoch - 5ms/step
# Epoch 84/1000
# 41/41 - 0s - loss: 1.9531 - accuracy: 0.8783 - 185ms/epoch - 5ms/step
# Epoch 85/1000
# 41/41 - 0s - loss: 1.9453 - accuracy: 0.8783 - 180ms/epoch - 4ms/step
# Epoch 86/1000
# 41/41 - 0s - loss: 1.9368 - accuracy: 0.8783 - 187ms/epoch - 5ms/step
# Epoch 87/1000
# 41/41 - 0s - loss: 1.9293 - accuracy: 0.8783 - 198ms/epoch - 5ms/step
# Epoch 88/1000
# 41/41 - 0s - loss: 1.9213 - accuracy: 0.8783 - 184ms/epoch - 4ms/step
# Epoch 89/1000
# 41/41 - 0s - loss: 1.9137 - accuracy: 0.8783 - 185ms/epoch - 5ms/step
# Epoch 90/1000
# 41/41 - 0s - loss: 1.9058 - accuracy: 0.8783 - 185ms/epoch - 5ms/step
# Epoch 91/1000
# 41/41 - 0s - loss: 1.8985 - accuracy: 0.8783 - 184ms/epoch - 4ms/step
# Epoch 92/1000
# 41/41 - 0s - loss: 1.8909 - accuracy: 0.8783 - 182ms/epoch - 4ms/step
# Epoch 93/1000
# 41/41 - 0s - loss: 1.8833 - accuracy: 0.8783 - 201ms/epoch - 5ms/step
# Epoch 94/1000
# 41/41 - 0s - loss: 1.8756 - accuracy: 0.8783 - 192ms/epoch - 5ms/step
# Epoch 95/1000
# 41/41 - 0s - loss: 1.8684 - accuracy: 0.8783 - 207ms/epoch - 5ms/step
# Epoch 96/1000
# 41/41 - 0s - loss: 1.8615 - accuracy: 0.8783 - 194ms/epoch - 5ms/step
# Epoch 97/1000
# 41/41 - 0s - loss: 1.8538 - accuracy: 0.8783 - 190ms/epoch - 5ms/step
# Epoch 98/1000
# 41/41 - 0s - loss: 1.8464 - accuracy: 0.8795 - 189ms/epoch - 5ms/step
# Epoch 99/1000
# 41/41 - 0s - loss: 1.8391 - accuracy: 0.8783 - 190ms/epoch - 5ms/step
# Epoch 100/1000
# 41/41 - 0s - loss: 1.8319 - accuracy: 0.8807 - 202ms/epoch - 5ms/step
# Epoch 101/1000
# 41/41 - 0s - loss: 1.8247 - accuracy: 0.8783 - 192ms/epoch - 5ms/step
# Epoch 102/1000
# 41/41 - 0s - loss: 1.8180 - accuracy: 0.8795 - 215ms/epoch - 5ms/step
# Epoch 103/1000
# 41/41 - 0s - loss: 1.8112 - accuracy: 0.8795 - 217ms/epoch - 5ms/step
# Epoch 104/1000
# 41/41 - 0s - loss: 1.8037 - accuracy: 0.8832 - 198ms/epoch - 5ms/step
# Epoch 105/1000
# 41/41 - 0s - loss: 1.7970 - accuracy: 0.8795 - 199ms/epoch - 5ms/step
# Epoch 106/1000
# 41/41 - 0s - loss: 1.7903 - accuracy: 0.8820 - 196ms/epoch - 5ms/step
# Epoch 107/1000
# 41/41 - 0s - loss: 1.7828 - accuracy: 0.8820 - 204ms/epoch - 5ms/step
# Epoch 108/1000
# 41/41 - 0s - loss: 1.7763 - accuracy: 0.8795 - 204ms/epoch - 5ms/step
# Epoch 109/1000
# 41/41 - 0s - loss: 1.7693 - accuracy: 0.8832 - 212ms/epoch - 5ms/step
# Epoch 110/1000
# 41/41 - 0s - loss: 1.7628 - accuracy: 0.8807 - 205ms/epoch - 5ms/step
# Epoch 111/1000
# 41/41 - 0s - loss: 1.7561 - accuracy: 0.8832 - 191ms/epoch - 5ms/step
# Epoch 112/1000
# 41/41 - 0s - loss: 1.7493 - accuracy: 0.8832 - 206ms/epoch - 5ms/step
# Epoch 113/1000
# 41/41 - 0s - loss: 1.7431 - accuracy: 0.8820 - 217ms/epoch - 5ms/step
# Epoch 114/1000
# 41/41 - 0s - loss: 1.7362 - accuracy: 0.8832 - 250ms/epoch - 6ms/step
# Epoch 115/1000
# 41/41 - 0s - loss: 1.7295 - accuracy: 0.8832 - 238ms/epoch - 6ms/step
# Epoch 116/1000
# 41/41 - 0s - loss: 1.7234 - accuracy: 0.8832 - 200ms/epoch - 5ms/step
# Epoch 117/1000
# 41/41 - 0s - loss: 1.7166 - accuracy: 0.8832 - 213ms/epoch - 5ms/step
# Epoch 118/1000
# 41/41 - 0s - loss: 1.7100 - accuracy: 0.8832 - 199ms/epoch - 5ms/step
# Epoch 119/1000
# 41/41 - 0s - loss: 1.7036 - accuracy: 0.8832 - 242ms/epoch - 6ms/step
# Epoch 120/1000
# 41/41 - 0s - loss: 1.6974 - accuracy: 0.8832 - 223ms/epoch - 5ms/step
# Epoch 121/1000
# 41/41 - 0s - loss: 1.6912 - accuracy: 0.8832 - 230ms/epoch - 6ms/step
# Epoch 122/1000
# 41/41 - 0s - loss: 1.6849 - accuracy: 0.8832 - 194ms/epoch - 5ms/step
# Epoch 123/1000
# 41/41 - 0s - loss: 1.6788 - accuracy: 0.8832 - 183ms/epoch - 4ms/step
# Epoch 124/1000
# 41/41 - 0s - loss: 1.6721 - accuracy: 0.8832 - 205ms/epoch - 5ms/step
# Epoch 125/1000
# 41/41 - 0s - loss: 1.6660 - accuracy: 0.8832 - 185ms/epoch - 5ms/step
# Epoch 126/1000
# 41/41 - 0s - loss: 1.6599 - accuracy: 0.8832 - 196ms/epoch - 5ms/step
# Epoch 127/1000
# 41/41 - 0s - loss: 1.6539 - accuracy: 0.8832 - 238ms/epoch - 6ms/step
# Epoch 128/1000
# 41/41 - 0s - loss: 1.6478 - accuracy: 0.8832 - 260ms/epoch - 6ms/step
# Epoch 129/1000
# 41/41 - 0s - loss: 1.6420 - accuracy: 0.8832 - 319ms/epoch - 8ms/step
# Epoch 130/1000
# 41/41 - 0s - loss: 1.6359 - accuracy: 0.8832 - 196ms/epoch - 5ms/step
# Epoch 131/1000
# 41/41 - 0s - loss: 1.6299 - accuracy: 0.8832 - 166ms/epoch - 4ms/step
# Epoch 132/1000
# 41/41 - 0s - loss: 1.6239 - accuracy: 0.8832 - 176ms/epoch - 4ms/step
# Epoch 133/1000
# 41/41 - 0s - loss: 1.6179 - accuracy: 0.8832 - 175ms/epoch - 4ms/step
# Epoch 134/1000
# 41/41 - 0s - loss: 1.6121 - accuracy: 0.8832 - 164ms/epoch - 4ms/step
# Epoch 135/1000
# 41/41 - 0s - loss: 1.6066 - accuracy: 0.8832 - 165ms/epoch - 4ms/step
# Epoch 136/1000
# 41/41 - 0s - loss: 1.6006 - accuracy: 0.8832 - 200ms/epoch - 5ms/step
# Epoch 137/1000
# 41/41 - 0s - loss: 1.5948 - accuracy: 0.8832 - 179ms/epoch - 4ms/step
# Epoch 138/1000
# 41/41 - 0s - loss: 1.5890 - accuracy: 0.8832 - 188ms/epoch - 5ms/step
# Epoch 139/1000
# 41/41 - 0s - loss: 1.5832 - accuracy: 0.8832 - 188ms/epoch - 5ms/step
# Epoch 140/1000
# 41/41 - 0s - loss: 1.5774 - accuracy: 0.8832 - 236ms/epoch - 6ms/step
# Epoch 141/1000
# 41/41 - 0s - loss: 1.5721 - accuracy: 0.8832 - 166ms/epoch - 4ms/step
# Epoch 142/1000
# 41/41 - 0s - loss: 1.5664 - accuracy: 0.8832 - 169ms/epoch - 4ms/step
# Epoch 143/1000
# 41/41 - 0s - loss: 1.5607 - accuracy: 0.8832 - 171ms/epoch - 4ms/step
# Epoch 144/1000
# 41/41 - 0s - loss: 1.5552 - accuracy: 0.8832 - 166ms/epoch - 4ms/step
# Epoch 145/1000
# 41/41 - 0s - loss: 1.5497 - accuracy: 0.8832 - 156ms/epoch - 4ms/step
# Epoch 146/1000
# 41/41 - 0s - loss: 1.5442 - accuracy: 0.8832 - 156ms/epoch - 4ms/step
# Epoch 147/1000
# 41/41 - 0s - loss: 1.5389 - accuracy: 0.8832 - 170ms/epoch - 4ms/step
# Epoch 148/1000
# 41/41 - 0s - loss: 1.5334 - accuracy: 0.8832 - 153ms/epoch - 4ms/step
# Epoch 149/1000
# 41/41 - 0s - loss: 1.5278 - accuracy: 0.8832 - 166ms/epoch - 4ms/step
# Epoch 150/1000
# 41/41 - 0s - loss: 1.5226 - accuracy: 0.8832 - 173ms/epoch - 4ms/step
# Epoch 151/1000
# 41/41 - 0s - loss: 1.5170 - accuracy: 0.8832 - 177ms/epoch - 4ms/step
# Epoch 152/1000
# 41/41 - 0s - loss: 1.5118 - accuracy: 0.8832 - 232ms/epoch - 6ms/step
# Epoch 153/1000
# 41/41 - 0s - loss: 1.5068 - accuracy: 0.8832 - 205ms/epoch - 5ms/step
# Epoch 154/1000
# 41/41 - 0s - loss: 1.5013 - accuracy: 0.8832 - 222ms/epoch - 5ms/step
# Epoch 155/1000
# 41/41 - 0s - loss: 1.4960 - accuracy: 0.8832 - 182ms/epoch - 4ms/step
# Epoch 156/1000
# 41/41 - 0s - loss: 1.4907 - accuracy: 0.8832 - 204ms/epoch - 5ms/step
# Epoch 157/1000
# 41/41 - 0s - loss: 1.4859 - accuracy: 0.8832 - 187ms/epoch - 5ms/step
# Epoch 158/1000
# 41/41 - 0s - loss: 1.4806 - accuracy: 0.8832 - 186ms/epoch - 5ms/step
# Epoch 159/1000
# 41/41 - 0s - loss: 1.4752 - accuracy: 0.8832 - 186ms/epoch - 5ms/step
# Epoch 160/1000
# 41/41 - 0s - loss: 1.4704 - accuracy: 0.8832 - 191ms/epoch - 5ms/step
# Epoch 161/1000
# 41/41 - 0s - loss: 1.4650 - accuracy: 0.8832 - 180ms/epoch - 4ms/step
# Epoch 162/1000
# 41/41 - 0s - loss: 1.4599 - accuracy: 0.8832 - 178ms/epoch - 4ms/step
# Epoch 163/1000
# 41/41 - 0s - loss: 1.4547 - accuracy: 0.8832 - 171ms/epoch - 4ms/step
# Epoch 164/1000
# 41/41 - 0s - loss: 1.4501 - accuracy: 0.8832 - 174ms/epoch - 4ms/step
# Epoch 165/1000
# 41/41 - 0s - loss: 1.4449 - accuracy: 0.8832 - 188ms/epoch - 5ms/step
# Epoch 166/1000
# 41/41 - 0s - loss: 1.4399 - accuracy: 0.8832 - 236ms/epoch - 6ms/step
# Epoch 167/1000
# 41/41 - 0s - loss: 1.4349 - accuracy: 0.8832 - 276ms/epoch - 7ms/step
# Epoch 168/1000
# 41/41 - 0s - loss: 1.4302 - accuracy: 0.8832 - 207ms/epoch - 5ms/step
# Epoch 169/1000
# 41/41 - 0s - loss: 1.4252 - accuracy: 0.8832 - 185ms/epoch - 5ms/step
# Epoch 170/1000
# 41/41 - 0s - loss: 1.4202 - accuracy: 0.8832 - 183ms/epoch - 4ms/step
# Epoch 171/1000
# 41/41 - 0s - loss: 1.4155 - accuracy: 0.8832 - 168ms/epoch - 4ms/step
# Epoch 172/1000
# 41/41 - 0s - loss: 1.4107 - accuracy: 0.8832 - 181ms/epoch - 4ms/step
# Epoch 173/1000
# 41/41 - 0s - loss: 1.4057 - accuracy: 0.8832 - 171ms/epoch - 4ms/step
# Epoch 174/1000
# 41/41 - 0s - loss: 1.4010 - accuracy: 0.8832 - 182ms/epoch - 4ms/step
# Epoch 175/1000
# 41/41 - 0s - loss: 1.3963 - accuracy: 0.8832 - 180ms/epoch - 4ms/step
# Epoch 176/1000
# 41/41 - 0s - loss: 1.3914 - accuracy: 0.8832 - 167ms/epoch - 4ms/step
# Epoch 177/1000
# 41/41 - 0s - loss: 1.3866 - accuracy: 0.8832 - 168ms/epoch - 4ms/step
# Epoch 178/1000
# 41/41 - 0s - loss: 1.3818 - accuracy: 0.8832 - 224ms/epoch - 5ms/step
# Epoch 179/1000
# 41/41 - 0s - loss: 1.3773 - accuracy: 0.8832 - 241ms/epoch - 6ms/step
# Epoch 180/1000
# 41/41 - 0s - loss: 1.3727 - accuracy: 0.8832 - 238ms/epoch - 6ms/step
# Epoch 181/1000
# 41/41 - 0s - loss: 1.3679 - accuracy: 0.8832 - 189ms/epoch - 5ms/step
# Epoch 182/1000
# 41/41 - 0s - loss: 1.3638 - accuracy: 0.8832 - 204ms/epoch - 5ms/step
# Epoch 183/1000
# 41/41 - 0s - loss: 1.3589 - accuracy: 0.8832 - 210ms/epoch - 5ms/step
# Epoch 184/1000
# 41/41 - 0s - loss: 1.3542 - accuracy: 0.8832 - 188ms/epoch - 5ms/step
# Epoch 185/1000
# 41/41 - 0s - loss: 1.3496 - accuracy: 0.8832 - 178ms/epoch - 4ms/step
# Epoch 186/1000
# 41/41 - 0s - loss: 1.3450 - accuracy: 0.8832 - 209ms/epoch - 5ms/step
# Epoch 187/1000
# 41/41 - 0s - loss: 1.3405 - accuracy: 0.8832 - 209ms/epoch - 5ms/step
# Epoch 188/1000
# 41/41 - 0s - loss: 1.3361 - accuracy: 0.8832 - 190ms/epoch - 5ms/step
# Epoch 189/1000
# 41/41 - 0s - loss: 1.3317 - accuracy: 0.8832 - 179ms/epoch - 4ms/step
# Epoch 190/1000
# 41/41 - 0s - loss: 1.3276 - accuracy: 0.8832 - 237ms/epoch - 6ms/step
# Epoch 191/1000
# 41/41 - 0s - loss: 1.3226 - accuracy: 0.8832 - 193ms/epoch - 5ms/step
# Epoch 192/1000
# 41/41 - 0s - loss: 1.3182 - accuracy: 0.8832 - 192ms/epoch - 5ms/step
# Epoch 193/1000
# 41/41 - 0s - loss: 1.3137 - accuracy: 0.8832 - 209ms/epoch - 5ms/step
# Epoch 194/1000
# 41/41 - 0s - loss: 1.3094 - accuracy: 0.8832 - 222ms/epoch - 5ms/step
# Epoch 195/1000
# 41/41 - 0s - loss: 1.3050 - accuracy: 0.8832 - 199ms/epoch - 5ms/step
# Epoch 196/1000
# 41/41 - 0s - loss: 1.3005 - accuracy: 0.8832 - 176ms/epoch - 4ms/step
# Epoch 197/1000
# 41/41 - 0s - loss: 1.2963 - accuracy: 0.8832 - 264ms/epoch - 6ms/step
# Epoch 198/1000
# 41/41 - 0s - loss: 1.2922 - accuracy: 0.8832 - 202ms/epoch - 5ms/step
# Epoch 199/1000
# 41/41 - 0s - loss: 1.2880 - accuracy: 0.8832 - 198ms/epoch - 5ms/step
# Epoch 200/1000
# 41/41 - 0s - loss: 1.2834 - accuracy: 0.8832 - 186ms/epoch - 5ms/step
# Epoch 201/1000
# 41/41 - 0s - loss: 1.2793 - accuracy: 0.8832 - 184ms/epoch - 4ms/step
# Epoch 202/1000
# 41/41 - 0s - loss: 1.2748 - accuracy: 0.8832 - 192ms/epoch - 5ms/step
# Epoch 203/1000
# 41/41 - 0s - loss: 1.2706 - accuracy: 0.8832 - 181ms/epoch - 4ms/step
# Epoch 204/1000
# 41/41 - 0s - loss: 1.2665 - accuracy: 0.8832 - 163ms/epoch - 4ms/step
# Epoch 205/1000
# 41/41 - 0s - loss: 1.2622 - accuracy: 0.8845 - 168ms/epoch - 4ms/step
# Epoch 206/1000
# 41/41 - 0s - loss: 1.2582 - accuracy: 0.8832 - 177ms/epoch - 4ms/step
# Epoch 207/1000
# 41/41 - 0s - loss: 1.2540 - accuracy: 0.8832 - 166ms/epoch - 4ms/step
# Epoch 208/1000
# 41/41 - 0s - loss: 1.2499 - accuracy: 0.8832 - 181ms/epoch - 4ms/step
# Epoch 209/1000
# 41/41 - 0s - loss: 1.2456 - accuracy: 0.8832 - 219ms/epoch - 5ms/step
# Epoch 210/1000
# 41/41 - 0s - loss: 1.2415 - accuracy: 0.8832 - 181ms/epoch - 4ms/step
# Epoch 211/1000
# 41/41 - 0s - loss: 1.2374 - accuracy: 0.8845 - 189ms/epoch - 5ms/step
# Epoch 212/1000
# 41/41 - 0s - loss: 1.2334 - accuracy: 0.8832 - 187ms/epoch - 5ms/step
# Epoch 213/1000
# 41/41 - 0s - loss: 1.2294 - accuracy: 0.8845 - 188ms/epoch - 5ms/step
# Epoch 214/1000
# 41/41 - 0s - loss: 1.2253 - accuracy: 0.8845 - 186ms/epoch - 5ms/step
# Epoch 215/1000
# 41/41 - 0s - loss: 1.2215 - accuracy: 0.8845 - 196ms/epoch - 5ms/step
# Epoch 216/1000
# 41/41 - 0s - loss: 1.2173 - accuracy: 0.8845 - 194ms/epoch - 5ms/step
# Epoch 217/1000
# 41/41 - 0s - loss: 1.2135 - accuracy: 0.8870 - 195ms/epoch - 5ms/step
# Epoch 218/1000
# 41/41 - 0s - loss: 1.2094 - accuracy: 0.8857 - 196ms/epoch - 5ms/step
# Epoch 219/1000
# 41/41 - 0s - loss: 1.2054 - accuracy: 0.8981 - 187ms/epoch - 5ms/step
# Epoch 220/1000
# 41/41 - 0s - loss: 1.2017 - accuracy: 0.8870 - 188ms/epoch - 5ms/step
# Epoch 221/1000
# 41/41 - 0s - loss: 1.1977 - accuracy: 0.8857 - 196ms/epoch - 5ms/step
# Epoch 222/1000
# 41/41 - 0s - loss: 1.1941 - accuracy: 0.8907 - 198ms/epoch - 5ms/step
# Epoch 223/1000
# 41/41 - 0s - loss: 1.1899 - accuracy: 0.8981 - 208ms/epoch - 5ms/step
# Epoch 224/1000
# 41/41 - 0s - loss: 1.1861 - accuracy: 0.9019 - 193ms/epoch - 5ms/step
# Epoch 225/1000
# 41/41 - 0s - loss: 1.1823 - accuracy: 0.9019 - 201ms/epoch - 5ms/step
# Epoch 226/1000
# 41/41 - 0s - loss: 1.1786 - accuracy: 0.9031 - 199ms/epoch - 5ms/step
# Epoch 227/1000
# 41/41 - 0s - loss: 1.1746 - accuracy: 0.9056 - 197ms/epoch - 5ms/step
# Epoch 228/1000
# 41/41 - 0s - loss: 1.1708 - accuracy: 0.9056 - 218ms/epoch - 5ms/step
# Epoch 229/1000
# 41/41 - 0s - loss: 1.1671 - accuracy: 0.9068 - 217ms/epoch - 5ms/step
# Epoch 230/1000
# 41/41 - 0s - loss: 1.1634 - accuracy: 0.9118 - 193ms/epoch - 5ms/step
# Epoch 231/1000
# 41/41 - 0s - loss: 1.1597 - accuracy: 0.9043 - 206ms/epoch - 5ms/step
# Epoch 232/1000
# 41/41 - 0s - loss: 1.1559 - accuracy: 0.9106 - 207ms/epoch - 5ms/step
# Epoch 233/1000
# 41/41 - 0s - loss: 1.1523 - accuracy: 0.9130 - 213ms/epoch - 5ms/step
# Epoch 234/1000
# 41/41 - 0s - loss: 1.1485 - accuracy: 0.9106 - 203ms/epoch - 5ms/step
# Epoch 235/1000
# 41/41 - 0s - loss: 1.1451 - accuracy: 0.9118 - 226ms/epoch - 6ms/step
# Epoch 236/1000
# 41/41 - 0s - loss: 1.1412 - accuracy: 0.9143 - 203ms/epoch - 5ms/step
# Epoch 237/1000
# 41/41 - 0s - loss: 1.1376 - accuracy: 0.9143 - 203ms/epoch - 5ms/step
# Epoch 238/1000
# 41/41 - 0s - loss: 1.1337 - accuracy: 0.9143 - 214ms/epoch - 5ms/step
# Epoch 239/1000
# 41/41 - 0s - loss: 1.1303 - accuracy: 0.9130 - 198ms/epoch - 5ms/step
# Epoch 240/1000
# 41/41 - 0s - loss: 1.1266 - accuracy: 0.9155 - 193ms/epoch - 5ms/step
# Epoch 241/1000
# 41/41 - 0s - loss: 1.1231 - accuracy: 0.9155 - 206ms/epoch - 5ms/step
# Epoch 242/1000
# 41/41 - 0s - loss: 1.1197 - accuracy: 0.9168 - 202ms/epoch - 5ms/step
# Epoch 243/1000
# 41/41 - 0s - loss: 1.1161 - accuracy: 0.9168 - 199ms/epoch - 5ms/step
# Epoch 244/1000
# 41/41 - 0s - loss: 1.1124 - accuracy: 0.9180 - 172ms/epoch - 4ms/step
# Epoch 245/1000
# 41/41 - 0s - loss: 1.1090 - accuracy: 0.9180 - 171ms/epoch - 4ms/step
# Epoch 246/1000
# 41/41 - 0s - loss: 1.1054 - accuracy: 0.9180 - 174ms/epoch - 4ms/step
# Epoch 247/1000
# 41/41 - 0s - loss: 1.1019 - accuracy: 0.9180 - 191ms/epoch - 5ms/step
# Epoch 248/1000
# 41/41 - 0s - loss: 1.0985 - accuracy: 0.9180 - 186ms/epoch - 5ms/step
# Epoch 249/1000
# 41/41 - 0s - loss: 1.0950 - accuracy: 0.9180 - 191ms/epoch - 5ms/step
# Epoch 250/1000
# 41/41 - 0s - loss: 1.0916 - accuracy: 0.9205 - 188ms/epoch - 5ms/step
# Epoch 251/1000
# 41/41 - 0s - loss: 1.0882 - accuracy: 0.9180 - 186ms/epoch - 5ms/step
# Epoch 252/1000
# 41/41 - 0s - loss: 1.0848 - accuracy: 0.9217 - 182ms/epoch - 4ms/step
# Epoch 253/1000
# 41/41 - 0s - loss: 1.0812 - accuracy: 0.9217 - 179ms/epoch - 4ms/step
# Epoch 254/1000
# 41/41 - 0s - loss: 1.0779 - accuracy: 0.9205 - 180ms/epoch - 4ms/step
# Epoch 255/1000
# 41/41 - 0s - loss: 1.0745 - accuracy: 0.9217 - 193ms/epoch - 5ms/step
# Epoch 256/1000
# 41/41 - 0s - loss: 1.0711 - accuracy: 0.9255 - 176ms/epoch - 4ms/step
# Epoch 257/1000
# 41/41 - 0s - loss: 1.0677 - accuracy: 0.9255 - 181ms/epoch - 4ms/step
# Epoch 258/1000
# 41/41 - 0s - loss: 1.0644 - accuracy: 0.9255 - 202ms/epoch - 5ms/step
# Epoch 259/1000
# 41/41 - 0s - loss: 1.0612 - accuracy: 0.9255 - 195ms/epoch - 5ms/step
# Epoch 260/1000
# 41/41 - 0s - loss: 1.0578 - accuracy: 0.9255 - 182ms/epoch - 4ms/step
# Epoch 261/1000
# 41/41 - 0s - loss: 1.0544 - accuracy: 0.9267 - 190ms/epoch - 5ms/step
# Epoch 262/1000
# 41/41 - 0s - loss: 1.0511 - accuracy: 0.9242 - 205ms/epoch - 5ms/step
# Epoch 263/1000
# 41/41 - 0s - loss: 1.0480 - accuracy: 0.9267 - 192ms/epoch - 5ms/step
# Epoch 264/1000
# 41/41 - 0s - loss: 1.0447 - accuracy: 0.9267 - 205ms/epoch - 5ms/step
# Epoch 265/1000
# 41/41 - 0s - loss: 1.0414 - accuracy: 0.9280 - 218ms/epoch - 5ms/step
# Epoch 266/1000
# 41/41 - 0s - loss: 1.0382 - accuracy: 0.9267 - 190ms/epoch - 5ms/step
# Epoch 267/1000
# 41/41 - 0s - loss: 1.0349 - accuracy: 0.9280 - 216ms/epoch - 5ms/step
# Epoch 268/1000
# 41/41 - 0s - loss: 1.0318 - accuracy: 0.9280 - 245ms/epoch - 6ms/step
# Epoch 269/1000
# 41/41 - 0s - loss: 1.0286 - accuracy: 0.9280 - 184ms/epoch - 4ms/step
# Epoch 270/1000
# 41/41 - 0s - loss: 1.0253 - accuracy: 0.9280 - 172ms/epoch - 4ms/step
# Epoch 271/1000
# 41/41 - 0s - loss: 1.0221 - accuracy: 0.9304 - 204ms/epoch - 5ms/step
# Epoch 272/1000
# 41/41 - 0s - loss: 1.0189 - accuracy: 0.9342 - 274ms/epoch - 7ms/step
# Epoch 273/1000
# 41/41 - 0s - loss: 1.0159 - accuracy: 0.9292 - 188ms/epoch - 5ms/step
# Epoch 274/1000
# 41/41 - 0s - loss: 1.0126 - accuracy: 0.9304 - 170ms/epoch - 4ms/step
# Epoch 275/1000
# 41/41 - 0s - loss: 1.0095 - accuracy: 0.9354 - 201ms/epoch - 5ms/step
# Epoch 276/1000
# 41/41 - 0s - loss: 1.0064 - accuracy: 0.9304 - 223ms/epoch - 5ms/step
# Epoch 277/1000
# 41/41 - 0s - loss: 1.0033 - accuracy: 0.9304 - 177ms/epoch - 4ms/step
# Epoch 278/1000
# 41/41 - 0s - loss: 1.0001 - accuracy: 0.9379 - 184ms/epoch - 4ms/step
# Epoch 279/1000
# 41/41 - 0s - loss: 0.9970 - accuracy: 0.9354 - 157ms/epoch - 4ms/step
# Epoch 280/1000
# 41/41 - 0s - loss: 0.9939 - accuracy: 0.9391 - 161ms/epoch - 4ms/step
# Epoch 281/1000
# 41/41 - 0s - loss: 0.9908 - accuracy: 0.9366 - 193ms/epoch - 5ms/step
# Epoch 282/1000
# 41/41 - 0s - loss: 0.9879 - accuracy: 0.9391 - 170ms/epoch - 4ms/step
# Epoch 283/1000
# 41/41 - 0s - loss: 0.9850 - accuracy: 0.9379 - 175ms/epoch - 4ms/step
# Epoch 284/1000
# 41/41 - 0s - loss: 0.9818 - accuracy: 0.9391 - 184ms/epoch - 4ms/step
# Epoch 285/1000
# 41/41 - 0s - loss: 0.9788 - accuracy: 0.9391 - 190ms/epoch - 5ms/step
# Epoch 286/1000
# 41/41 - 0s - loss: 0.9756 - accuracy: 0.9416 - 189ms/epoch - 5ms/step
# Epoch 287/1000
# 41/41 - 0s - loss: 0.9727 - accuracy: 0.9391 - 185ms/epoch - 5ms/step
# Epoch 288/1000
# 41/41 - 0s - loss: 0.9697 - accuracy: 0.9429 - 249ms/epoch - 6ms/step
# Epoch 289/1000
# 41/41 - 0s - loss: 0.9668 - accuracy: 0.9404 - 204ms/epoch - 5ms/step
# Epoch 290/1000
# 41/41 - 0s - loss: 0.9638 - accuracy: 0.9416 - 192ms/epoch - 5ms/step
# Epoch 291/1000
# 41/41 - 0s - loss: 0.9611 - accuracy: 0.9404 - 190ms/epoch - 5ms/step
# Epoch 292/1000
# 41/41 - 0s - loss: 0.9580 - accuracy: 0.9429 - 196ms/epoch - 5ms/step
# Epoch 293/1000
# 41/41 - 0s - loss: 0.9551 - accuracy: 0.9429 - 209ms/epoch - 5ms/step
# Epoch 294/1000
# 41/41 - 0s - loss: 0.9520 - accuracy: 0.9429 - 203ms/epoch - 5ms/step
# Epoch 295/1000
# 41/41 - 0s - loss: 0.9493 - accuracy: 0.9429 - 201ms/epoch - 5ms/step
# Epoch 296/1000
# 41/41 - 0s - loss: 0.9463 - accuracy: 0.9429 - 190ms/epoch - 5ms/step
# Epoch 297/1000
# 41/41 - 0s - loss: 0.9434 - accuracy: 0.9429 - 205ms/epoch - 5ms/step
# Epoch 298/1000
# 41/41 - 0s - loss: 0.9406 - accuracy: 0.9429 - 212ms/epoch - 5ms/step
# Epoch 299/1000
# 41/41 - 0s - loss: 0.9377 - accuracy: 0.9429 - 195ms/epoch - 5ms/step
# Epoch 300/1000
# 41/41 - 0s - loss: 0.9348 - accuracy: 0.9429 - 207ms/epoch - 5ms/step
# Epoch 301/1000
# 41/41 - 0s - loss: 0.9319 - accuracy: 0.9429 - 197ms/epoch - 5ms/step
# Epoch 302/1000
# 41/41 - 0s - loss: 0.9290 - accuracy: 0.9429 - 195ms/epoch - 5ms/step
# Epoch 303/1000
# 41/41 - 0s - loss: 0.9264 - accuracy: 0.9429 - 207ms/epoch - 5ms/step
# Epoch 304/1000
# 41/41 - 0s - loss: 0.9234 - accuracy: 0.9429 - 225ms/epoch - 5ms/step
# Epoch 305/1000
# 41/41 - 0s - loss: 0.9206 - accuracy: 0.9429 - 203ms/epoch - 5ms/step
# Epoch 306/1000
# 41/41 - 0s - loss: 0.9178 - accuracy: 0.9429 - 208ms/epoch - 5ms/step
# Epoch 307/1000
# 41/41 - 0s - loss: 0.9150 - accuracy: 0.9429 - 209ms/epoch - 5ms/step
# Epoch 308/1000
# 41/41 - 0s - loss: 0.9123 - accuracy: 0.9429 - 207ms/epoch - 5ms/step
# Epoch 309/1000
# 41/41 - 0s - loss: 0.9095 - accuracy: 0.9429 - 212ms/epoch - 5ms/step
# Epoch 310/1000
# 41/41 - 0s - loss: 0.9070 - accuracy: 0.9429 - 212ms/epoch - 5ms/step
# Epoch 311/1000
# 41/41 - 0s - loss: 0.9040 - accuracy: 0.9429 - 207ms/epoch - 5ms/step
# Epoch 312/1000
# 41/41 - 0s - loss: 0.9012 - accuracy: 0.9429 - 227ms/epoch - 6ms/step
# Epoch 313/1000
# 41/41 - 0s - loss: 0.8987 - accuracy: 0.9429 - 219ms/epoch - 5ms/step
# Epoch 314/1000
# 41/41 - 0s - loss: 0.8960 - accuracy: 0.9429 - 218ms/epoch - 5ms/step
# Epoch 315/1000
# 41/41 - 0s - loss: 0.8932 - accuracy: 0.9429 - 192ms/epoch - 5ms/step
# Epoch 316/1000
# 41/41 - 0s - loss: 0.8904 - accuracy: 0.9429 - 212ms/epoch - 5ms/step
# Epoch 317/1000
# 41/41 - 0s - loss: 0.8877 - accuracy: 0.9429 - 221ms/epoch - 5ms/step
# Epoch 318/1000
# 41/41 - 0s - loss: 0.8849 - accuracy: 0.9429 - 191ms/epoch - 5ms/step
# Epoch 319/1000
# 41/41 - 0s - loss: 0.8823 - accuracy: 0.9429 - 205ms/epoch - 5ms/step
# Epoch 320/1000
# 41/41 - 0s - loss: 0.8797 - accuracy: 0.9429 - 220ms/epoch - 5ms/step
# Epoch 321/1000
# 41/41 - 0s - loss: 0.8771 - accuracy: 0.9429 - 203ms/epoch - 5ms/step
# Epoch 322/1000
# 41/41 - 0s - loss: 0.8744 - accuracy: 0.9429 - 221ms/epoch - 5ms/step
# Epoch 323/1000
# 41/41 - 0s - loss: 0.8719 - accuracy: 0.9441 - 207ms/epoch - 5ms/step
# Epoch 324/1000
# 41/41 - 0s - loss: 0.8691 - accuracy: 0.9429 - 231ms/epoch - 6ms/step
# Epoch 325/1000
# 41/41 - 0s - loss: 0.8666 - accuracy: 0.9441 - 188ms/epoch - 5ms/step
# Epoch 326/1000
# 41/41 - 0s - loss: 0.8639 - accuracy: 0.9429 - 202ms/epoch - 5ms/step
# Epoch 327/1000
# 41/41 - 0s - loss: 0.8613 - accuracy: 0.9441 - 209ms/epoch - 5ms/step
# Epoch 328/1000
# 41/41 - 0s - loss: 0.8589 - accuracy: 0.9453 - 209ms/epoch - 5ms/step
# Epoch 329/1000
# 41/41 - 0s - loss: 0.8562 - accuracy: 0.9441 - 208ms/epoch - 5ms/step
# Epoch 330/1000
# 41/41 - 0s - loss: 0.8537 - accuracy: 0.9441 - 223ms/epoch - 5ms/step
# Epoch 331/1000
# 41/41 - 0s - loss: 0.8509 - accuracy: 0.9441 - 187ms/epoch - 5ms/step
# Epoch 332/1000
# 41/41 - 0s - loss: 0.8485 - accuracy: 0.9466 - 174ms/epoch - 4ms/step
# Epoch 333/1000
# 41/41 - 0s - loss: 0.8459 - accuracy: 0.9441 - 175ms/epoch - 4ms/step
# Epoch 334/1000
# 41/41 - 0s - loss: 0.8433 - accuracy: 0.9453 - 172ms/epoch - 4ms/step
# Epoch 335/1000
# 41/41 - 0s - loss: 0.8409 - accuracy: 0.9466 - 181ms/epoch - 4ms/step
# Epoch 336/1000
# 41/41 - 0s - loss: 0.8384 - accuracy: 0.9441 - 188ms/epoch - 5ms/step
# Epoch 337/1000
# 41/41 - 0s - loss: 0.8357 - accuracy: 0.9478 - 177ms/epoch - 4ms/step
# Epoch 338/1000
# 41/41 - 0s - loss: 0.8332 - accuracy: 0.9466 - 175ms/epoch - 4ms/step
# Epoch 339/1000
# 41/41 - 0s - loss: 0.8306 - accuracy: 0.9478 - 177ms/epoch - 4ms/step
# Epoch 340/1000
# 41/41 - 0s - loss: 0.8283 - accuracy: 0.9478 - 175ms/epoch - 4ms/step
# Epoch 341/1000
# 41/41 - 0s - loss: 0.8257 - accuracy: 0.9478 - 200ms/epoch - 5ms/step
# Epoch 342/1000
# 41/41 - 0s - loss: 0.8232 - accuracy: 0.9478 - 210ms/epoch - 5ms/step
# Epoch 343/1000
# 41/41 - 0s - loss: 0.8207 - accuracy: 0.9478 - 201ms/epoch - 5ms/step
# Epoch 344/1000
# 41/41 - 0s - loss: 0.8184 - accuracy: 0.9478 - 209ms/epoch - 5ms/step
# Epoch 345/1000
# 41/41 - 0s - loss: 0.8158 - accuracy: 0.9503 - 222ms/epoch - 5ms/step
# Epoch 346/1000
# 41/41 - 0s - loss: 0.8135 - accuracy: 0.9478 - 215ms/epoch - 5ms/step
# Epoch 347/1000
# 41/41 - 0s - loss: 0.8111 - accuracy: 0.9503 - 221ms/epoch - 5ms/step
# Epoch 348/1000
# 41/41 - 0s - loss: 0.8086 - accuracy: 0.9503 - 208ms/epoch - 5ms/step
# Epoch 349/1000
# 41/41 - 0s - loss: 0.8062 - accuracy: 0.9516 - 200ms/epoch - 5ms/step
# Epoch 350/1000
# 41/41 - 0s - loss: 0.8036 - accuracy: 0.9516 - 204ms/epoch - 5ms/step
# Epoch 351/1000
# 41/41 - 0s - loss: 0.8013 - accuracy: 0.9528 - 352ms/epoch - 9ms/step
# Epoch 352/1000
# 41/41 - 0s - loss: 0.7988 - accuracy: 0.9528 - 168ms/epoch - 4ms/step
# Epoch 353/1000
# 41/41 - 0s - loss: 0.7964 - accuracy: 0.9540 - 192ms/epoch - 5ms/step
# Epoch 354/1000
# 41/41 - 0s - loss: 0.7941 - accuracy: 0.9540 - 174ms/epoch - 4ms/step
# Epoch 355/1000
# 41/41 - 0s - loss: 0.7916 - accuracy: 0.9528 - 173ms/epoch - 4ms/step
# Epoch 356/1000
# 41/41 - 0s - loss: 0.7891 - accuracy: 0.9540 - 180ms/epoch - 4ms/step
# Epoch 357/1000
# 41/41 - 0s - loss: 0.7869 - accuracy: 0.9540 - 172ms/epoch - 4ms/step
# Epoch 358/1000
# 41/41 - 0s - loss: 0.7845 - accuracy: 0.9540 - 158ms/epoch - 4ms/step
# Epoch 359/1000
# 41/41 - 0s - loss: 0.7821 - accuracy: 0.9540 - 174ms/epoch - 4ms/step
# Epoch 360/1000
# 41/41 - 0s - loss: 0.7798 - accuracy: 0.9540 - 165ms/epoch - 4ms/step
# Epoch 361/1000
# 41/41 - 0s - loss: 0.7775 - accuracy: 0.9540 - 166ms/epoch - 4ms/step
# Epoch 362/1000
# 41/41 - 0s - loss: 0.7751 - accuracy: 0.9540 - 169ms/epoch - 4ms/step
# Epoch 363/1000
# 41/41 - 0s - loss: 0.7727 - accuracy: 0.9540 - 184ms/epoch - 4ms/step
# Epoch 364/1000
# 41/41 - 0s - loss: 0.7707 - accuracy: 0.9540 - 173ms/epoch - 4ms/step
# Epoch 365/1000
# 41/41 - 0s - loss: 0.7680 - accuracy: 0.9540 - 188ms/epoch - 5ms/step
# Epoch 366/1000
# 41/41 - 0s - loss: 0.7657 - accuracy: 0.9540 - 194ms/epoch - 5ms/step
# Epoch 367/1000
# 41/41 - 0s - loss: 0.7634 - accuracy: 0.9540 - 187ms/epoch - 5ms/step
# Epoch 368/1000
# 41/41 - 0s - loss: 0.7612 - accuracy: 0.9553 - 198ms/epoch - 5ms/step
# Epoch 369/1000
# 41/41 - 0s - loss: 0.7589 - accuracy: 0.9540 - 187ms/epoch - 5ms/step
# Epoch 370/1000
# 41/41 - 0s - loss: 0.7567 - accuracy: 0.9553 - 207ms/epoch - 5ms/step
# Epoch 371/1000
# 41/41 - 0s - loss: 0.7545 - accuracy: 0.9540 - 189ms/epoch - 5ms/step
# Epoch 372/1000
# 41/41 - 0s - loss: 0.7520 - accuracy: 0.9553 - 183ms/epoch - 4ms/step
# Epoch 373/1000
# 41/41 - 0s - loss: 0.7497 - accuracy: 0.9553 - 194ms/epoch - 5ms/step
# Epoch 374/1000
# 41/41 - 0s - loss: 0.7474 - accuracy: 0.9565 - 198ms/epoch - 5ms/step
# Epoch 375/1000
# 41/41 - 0s - loss: 0.7452 - accuracy: 0.9553 - 206ms/epoch - 5ms/step
# Epoch 376/1000
# 41/41 - 0s - loss: 0.7430 - accuracy: 0.9565 - 195ms/epoch - 5ms/step
# Epoch 377/1000
# 41/41 - 0s - loss: 0.7407 - accuracy: 0.9565 - 226ms/epoch - 6ms/step
# Epoch 378/1000
# 41/41 - 0s - loss: 0.7385 - accuracy: 0.9578 - 216ms/epoch - 5ms/step
# Epoch 379/1000
# 41/41 - 0s - loss: 0.7361 - accuracy: 0.9565 - 200ms/epoch - 5ms/step
# Epoch 380/1000
# 41/41 - 0s - loss: 0.7339 - accuracy: 0.9578 - 246ms/epoch - 6ms/step
# Epoch 381/1000
# 41/41 - 0s - loss: 0.7317 - accuracy: 0.9590 - 188ms/epoch - 5ms/step
# Epoch 382/1000
# 41/41 - 0s - loss: 0.7295 - accuracy: 0.9578 - 163ms/epoch - 4ms/step
# Epoch 383/1000
# 41/41 - 0s - loss: 0.7272 - accuracy: 0.9590 - 168ms/epoch - 4ms/step
# Epoch 384/1000
# 41/41 - 0s - loss: 0.7251 - accuracy: 0.9590 - 197ms/epoch - 5ms/step
# Epoch 385/1000
# 41/41 - 0s - loss: 0.7229 - accuracy: 0.9590 - 186ms/epoch - 5ms/step
# Epoch 386/1000
# 41/41 - 0s - loss: 0.7207 - accuracy: 0.9590 - 194ms/epoch - 5ms/step
# Epoch 387/1000
# 41/41 - 0s - loss: 0.7184 - accuracy: 0.9590 - 171ms/epoch - 4ms/step
# Epoch 388/1000
# 41/41 - 0s - loss: 0.7164 - accuracy: 0.9590 - 161ms/epoch - 4ms/step
# Epoch 389/1000
# 41/41 - 0s - loss: 0.7141 - accuracy: 0.9590 - 166ms/epoch - 4ms/step
# Epoch 390/1000
# 41/41 - 0s - loss: 0.7120 - accuracy: 0.9590 - 174ms/epoch - 4ms/step
# Epoch 391/1000
# 41/41 - 0s - loss: 0.7099 - accuracy: 0.9590 - 179ms/epoch - 4ms/step
# Epoch 392/1000
# 41/41 - 0s - loss: 0.7077 - accuracy: 0.9590 - 191ms/epoch - 5ms/step
# Epoch 393/1000
# 41/41 - 0s - loss: 0.7056 - accuracy: 0.9590 - 184ms/epoch - 4ms/step
# Epoch 394/1000
# 41/41 - 0s - loss: 0.7034 - accuracy: 0.9590 - 186ms/epoch - 5ms/step
# Epoch 395/1000
# 41/41 - 0s - loss: 0.7013 - accuracy: 0.9590 - 190ms/epoch - 5ms/step
# Epoch 396/1000
# 41/41 - 0s - loss: 0.6991 - accuracy: 0.9590 - 191ms/epoch - 5ms/step
# Epoch 397/1000
# 41/41 - 0s - loss: 0.6970 - accuracy: 0.9602 - 186ms/epoch - 5ms/step
# Epoch 398/1000
# 41/41 - 0s - loss: 0.6948 - accuracy: 0.9590 - 194ms/epoch - 5ms/step
# Epoch 399/1000
# 41/41 - 0s - loss: 0.6929 - accuracy: 0.9590 - 205ms/epoch - 5ms/step
# Epoch 400/1000
# 41/41 - 0s - loss: 0.6907 - accuracy: 0.9627 - 199ms/epoch - 5ms/step
# Epoch 401/1000
# 41/41 - 0s - loss: 0.6888 - accuracy: 0.9602 - 205ms/epoch - 5ms/step
# Epoch 402/1000
# 41/41 - 0s - loss: 0.6865 - accuracy: 0.9602 - 183ms/epoch - 4ms/step
# Epoch 403/1000
# 41/41 - 0s - loss: 0.6847 - accuracy: 0.9627 - 183ms/epoch - 4ms/step
# Epoch 404/1000
# 41/41 - 0s - loss: 0.6823 - accuracy: 0.9602 - 191ms/epoch - 5ms/step
# Epoch 405/1000
# 41/41 - 0s - loss: 0.6803 - accuracy: 0.9627 - 195ms/epoch - 5ms/step
# Epoch 406/1000
# 41/41 - 0s - loss: 0.6783 - accuracy: 0.9602 - 193ms/epoch - 5ms/step
# Epoch 407/1000
# 41/41 - 0s - loss: 0.6762 - accuracy: 0.9627 - 193ms/epoch - 5ms/step
# Epoch 408/1000
# 41/41 - 0s - loss: 0.6741 - accuracy: 0.9627 - 196ms/epoch - 5ms/step
# Epoch 409/1000
# 41/41 - 0s - loss: 0.6723 - accuracy: 0.9627 - 197ms/epoch - 5ms/step
# Epoch 410/1000
# 41/41 - 0s - loss: 0.6702 - accuracy: 0.9627 - 194ms/epoch - 5ms/step
# Epoch 411/1000
# 41/41 - 0s - loss: 0.6682 - accuracy: 0.9615 - 206ms/epoch - 5ms/step
# Epoch 412/1000
# 41/41 - 0s - loss: 0.6662 - accuracy: 0.9627 - 189ms/epoch - 5ms/step
# Epoch 413/1000
# 41/41 - 0s - loss: 0.6642 - accuracy: 0.9627 - 192ms/epoch - 5ms/step
# Epoch 414/1000
# 41/41 - 0s - loss: 0.6623 - accuracy: 0.9627 - 189ms/epoch - 5ms/step
# Epoch 415/1000
# 41/41 - 0s - loss: 0.6602 - accuracy: 0.9627 - 185ms/epoch - 5ms/step
# Epoch 416/1000
# 41/41 - 0s - loss: 0.6582 - accuracy: 0.9627 - 209ms/epoch - 5ms/step
# Epoch 417/1000
# 41/41 - 0s - loss: 0.6563 - accuracy: 0.9627 - 194ms/epoch - 5ms/step
# Epoch 418/1000
# 41/41 - 0s - loss: 0.6543 - accuracy: 0.9627 - 224ms/epoch - 5ms/step
# Epoch 419/1000
# 41/41 - 0s - loss: 0.6525 - accuracy: 0.9627 - 199ms/epoch - 5ms/step
# Epoch 420/1000
# 41/41 - 0s - loss: 0.6506 - accuracy: 0.9627 - 190ms/epoch - 5ms/step
# Epoch 421/1000
# 41/41 - 0s - loss: 0.6485 - accuracy: 0.9627 - 193ms/epoch - 5ms/step
# Epoch 422/1000
# 41/41 - 0s - loss: 0.6466 - accuracy: 0.9627 - 190ms/epoch - 5ms/step
# Epoch 423/1000
# 41/41 - 0s - loss: 0.6446 - accuracy: 0.9627 - 201ms/epoch - 5ms/step
# Epoch 424/1000
# 41/41 - 0s - loss: 0.6428 - accuracy: 0.9640 - 197ms/epoch - 5ms/step
# Epoch 425/1000
# 41/41 - 0s - loss: 0.6410 - accuracy: 0.9627 - 192ms/epoch - 5ms/step
# Epoch 426/1000
# 41/41 - 0s - loss: 0.6389 - accuracy: 0.9627 - 201ms/epoch - 5ms/step
# Epoch 427/1000
# 41/41 - 0s - loss: 0.6370 - accuracy: 0.9640 - 209ms/epoch - 5ms/step
# Epoch 428/1000
# 41/41 - 0s - loss: 0.6352 - accuracy: 0.9640 - 199ms/epoch - 5ms/step
# Epoch 429/1000
# 41/41 - 0s - loss: 0.6334 - accuracy: 0.9640 - 195ms/epoch - 5ms/step
# Epoch 430/1000
# 41/41 - 0s - loss: 0.6314 - accuracy: 0.9640 - 192ms/epoch - 5ms/step
# Epoch 431/1000
# 41/41 - 0s - loss: 0.6296 - accuracy: 0.9652 - 196ms/epoch - 5ms/step
# Epoch 432/1000
# 41/41 - 0s - loss: 0.6277 - accuracy: 0.9640 - 204ms/epoch - 5ms/step
# Epoch 433/1000
# 41/41 - 0s - loss: 0.6257 - accuracy: 0.9652 - 198ms/epoch - 5ms/step
# Epoch 434/1000
# 41/41 - 0s - loss: 0.6240 - accuracy: 0.9640 - 195ms/epoch - 5ms/step
# Epoch 435/1000
# 41/41 - 0s - loss: 0.6220 - accuracy: 0.9652 - 194ms/epoch - 5ms/step
# Epoch 436/1000
# 41/41 - 0s - loss: 0.6202 - accuracy: 0.9665 - 192ms/epoch - 5ms/step
# Epoch 437/1000
# 41/41 - 0s - loss: 0.6185 - accuracy: 0.9665 - 193ms/epoch - 5ms/step
# Epoch 438/1000
# 41/41 - 0s - loss: 0.6166 - accuracy: 0.9665 - 196ms/epoch - 5ms/step
# Epoch 439/1000
# 41/41 - 0s - loss: 0.6148 - accuracy: 0.9665 - 195ms/epoch - 5ms/step
# Epoch 440/1000
# 41/41 - 0s - loss: 0.6131 - accuracy: 0.9665 - 196ms/epoch - 5ms/step
# Epoch 441/1000
# 41/41 - 0s - loss: 0.6111 - accuracy: 0.9677 - 194ms/epoch - 5ms/step
# Epoch 442/1000
# 41/41 - 0s - loss: 0.6093 - accuracy: 0.9665 - 183ms/epoch - 4ms/step
# Epoch 443/1000
# 41/41 - 0s - loss: 0.6076 - accuracy: 0.9677 - 204ms/epoch - 5ms/step
# Epoch 444/1000
# 41/41 - 0s - loss: 0.6058 - accuracy: 0.9702 - 194ms/epoch - 5ms/step
# Epoch 445/1000
# 41/41 - 0s - loss: 0.6040 - accuracy: 0.9677 - 190ms/epoch - 5ms/step
# Epoch 446/1000
# 41/41 - 0s - loss: 0.6022 - accuracy: 0.9677 - 199ms/epoch - 5ms/step
# Epoch 447/1000
# 41/41 - 0s - loss: 0.6004 - accuracy: 0.9702 - 191ms/epoch - 5ms/step
# Epoch 448/1000
# 41/41 - 0s - loss: 0.5986 - accuracy: 0.9689 - 214ms/epoch - 5ms/step
# Epoch 449/1000
# 41/41 - 0s - loss: 0.5969 - accuracy: 0.9702 - 195ms/epoch - 5ms/step
# Epoch 450/1000
# 41/41 - 0s - loss: 0.5952 - accuracy: 0.9702 - 221ms/epoch - 5ms/step
# Epoch 451/1000
# 41/41 - 0s - loss: 0.5934 - accuracy: 0.9689 - 200ms/epoch - 5ms/step
# Epoch 452/1000
# 41/41 - 0s - loss: 0.5916 - accuracy: 0.9702 - 190ms/epoch - 5ms/step
# Epoch 453/1000
# 41/41 - 0s - loss: 0.5899 - accuracy: 0.9702 - 198ms/epoch - 5ms/step
# Epoch 454/1000
# 41/41 - 0s - loss: 0.5882 - accuracy: 0.9702 - 192ms/epoch - 5ms/step
# Epoch 455/1000
# 41/41 - 0s - loss: 0.5864 - accuracy: 0.9702 - 187ms/epoch - 5ms/step
# Epoch 456/1000
# 41/41 - 0s - loss: 0.5848 - accuracy: 0.9702 - 199ms/epoch - 5ms/step
# Epoch 457/1000
# 41/41 - 0s - loss: 0.5831 - accuracy: 0.9702 - 190ms/epoch - 5ms/step
# Epoch 458/1000
# 41/41 - 0s - loss: 0.5813 - accuracy: 0.9702 - 192ms/epoch - 5ms/step
# Epoch 459/1000
# 41/41 - 0s - loss: 0.5797 - accuracy: 0.9702 - 206ms/epoch - 5ms/step
# Epoch 460/1000
# 41/41 - 0s - loss: 0.5778 - accuracy: 0.9702 - 191ms/epoch - 5ms/step
# Epoch 461/1000
# 41/41 - 0s - loss: 0.5762 - accuracy: 0.9702 - 199ms/epoch - 5ms/step
# Epoch 462/1000
# 41/41 - 0s - loss: 0.5744 - accuracy: 0.9702 - 187ms/epoch - 5ms/step
# Epoch 463/1000
# 41/41 - 0s - loss: 0.5728 - accuracy: 0.9702 - 204ms/epoch - 5ms/step
# Epoch 464/1000
# 41/41 - 0s - loss: 0.5711 - accuracy: 0.9702 - 191ms/epoch - 5ms/step
# Epoch 465/1000
# 41/41 - 0s - loss: 0.5694 - accuracy: 0.9702 - 191ms/epoch - 5ms/step
# Epoch 466/1000
# 41/41 - 0s - loss: 0.5677 - accuracy: 0.9702 - 206ms/epoch - 5ms/step
# Epoch 467/1000
# 41/41 - 0s - loss: 0.5662 - accuracy: 0.9702 - 188ms/epoch - 5ms/step
# Epoch 468/1000
# 41/41 - 0s - loss: 0.5644 - accuracy: 0.9702 - 213ms/epoch - 5ms/step
# Epoch 469/1000
# 41/41 - 0s - loss: 0.5627 - accuracy: 0.9702 - 201ms/epoch - 5ms/step
# Epoch 470/1000
# 41/41 - 0s - loss: 0.5610 - accuracy: 0.9702 - 198ms/epoch - 5ms/step
# Epoch 471/1000
# 41/41 - 0s - loss: 0.5595 - accuracy: 0.9702 - 199ms/epoch - 5ms/step
# Epoch 472/1000
# 41/41 - 0s - loss: 0.5578 - accuracy: 0.9702 - 193ms/epoch - 5ms/step
# Epoch 473/1000
# 41/41 - 0s - loss: 0.5561 - accuracy: 0.9702 - 191ms/epoch - 5ms/step
# Epoch 474/1000
# 41/41 - 0s - loss: 0.5545 - accuracy: 0.9702 - 191ms/epoch - 5ms/step
# Epoch 475/1000
# 41/41 - 0s - loss: 0.5529 - accuracy: 0.9702 - 196ms/epoch - 5ms/step
# Epoch 476/1000
# 41/41 - 0s - loss: 0.5512 - accuracy: 0.9702 - 193ms/epoch - 5ms/step
# Epoch 477/1000
# 41/41 - 0s - loss: 0.5496 - accuracy: 0.9714 - 194ms/epoch - 5ms/step
# Epoch 478/1000
# 41/41 - 0s - loss: 0.5480 - accuracy: 0.9702 - 211ms/epoch - 5ms/step
# Epoch 479/1000
# 41/41 - 0s - loss: 0.5463 - accuracy: 0.9702 - 194ms/epoch - 5ms/step
# Epoch 480/1000
# 41/41 - 0s - loss: 0.5448 - accuracy: 0.9702 - 194ms/epoch - 5ms/step
# Epoch 481/1000
# 41/41 - 0s - loss: 0.5431 - accuracy: 0.9727 - 191ms/epoch - 5ms/step
# Epoch 482/1000
# 41/41 - 0s - loss: 0.5416 - accuracy: 0.9702 - 200ms/epoch - 5ms/step
# Epoch 483/1000
# 41/41 - 0s - loss: 0.5399 - accuracy: 0.9702 - 195ms/epoch - 5ms/step
# Epoch 484/1000
# 41/41 - 0s - loss: 0.5385 - accuracy: 0.9714 - 192ms/epoch - 5ms/step
# Epoch 485/1000
# 41/41 - 0s - loss: 0.5368 - accuracy: 0.9714 - 193ms/epoch - 5ms/step
# Epoch 486/1000
# 41/41 - 0s - loss: 0.5352 - accuracy: 0.9739 - 213ms/epoch - 5ms/step
# Epoch 487/1000
# 41/41 - 0s - loss: 0.5336 - accuracy: 0.9776 - 195ms/epoch - 5ms/step
# Epoch 488/1000
# 41/41 - 0s - loss: 0.5320 - accuracy: 0.9752 - 200ms/epoch - 5ms/step
# Epoch 489/1000
# 41/41 - 0s - loss: 0.5304 - accuracy: 0.9739 - 194ms/epoch - 5ms/step
# Epoch 490/1000
# 41/41 - 0s - loss: 0.5289 - accuracy: 0.9714 - 203ms/epoch - 5ms/step
# Epoch 491/1000
# 41/41 - 0s - loss: 0.5273 - accuracy: 0.9814 - 199ms/epoch - 5ms/step
# Epoch 492/1000
# 41/41 - 0s - loss: 0.5257 - accuracy: 0.9801 - 191ms/epoch - 5ms/step
# Epoch 493/1000
# 41/41 - 0s - loss: 0.5242 - accuracy: 0.9764 - 199ms/epoch - 5ms/step
# Epoch 494/1000
# 41/41 - 0s - loss: 0.5227 - accuracy: 0.9789 - 191ms/epoch - 5ms/step
# Epoch 495/1000
# 41/41 - 0s - loss: 0.5212 - accuracy: 0.9814 - 190ms/epoch - 5ms/step
# Epoch 496/1000
# 41/41 - 0s - loss: 0.5197 - accuracy: 0.9814 - 191ms/epoch - 5ms/step
# Epoch 497/1000
# 41/41 - 0s - loss: 0.5182 - accuracy: 0.9814 - 193ms/epoch - 5ms/step
# Epoch 498/1000
# 41/41 - 0s - loss: 0.5165 - accuracy: 0.9814 - 205ms/epoch - 5ms/step
# Epoch 499/1000
# 41/41 - 0s - loss: 0.5150 - accuracy: 0.9839 - 197ms/epoch - 5ms/step
# Epoch 500/1000
# 41/41 - 0s - loss: 0.5136 - accuracy: 0.9839 - 194ms/epoch - 5ms/step
# Epoch 501/1000
# 41/41 - 0s - loss: 0.5120 - accuracy: 0.9839 - 188ms/epoch - 5ms/step
# Epoch 502/1000
# 41/41 - 0s - loss: 0.5104 - accuracy: 0.9839 - 191ms/epoch - 5ms/step
# Epoch 503/1000
# 41/41 - 0s - loss: 0.5089 - accuracy: 0.9851 - 197ms/epoch - 5ms/step
# Epoch 504/1000
# 41/41 - 0s - loss: 0.5074 - accuracy: 0.9839 - 208ms/epoch - 5ms/step
# Epoch 505/1000
# 41/41 - 0s - loss: 0.5060 - accuracy: 0.9876 - 202ms/epoch - 5ms/step
# Epoch 506/1000
# 41/41 - 0s - loss: 0.5043 - accuracy: 0.9876 - 217ms/epoch - 5ms/step
# Epoch 507/1000
# 41/41 - 0s - loss: 0.5031 - accuracy: 0.9876 - 317ms/epoch - 8ms/step
# Epoch 508/1000
# 41/41 - 0s - loss: 0.5016 - accuracy: 0.9863 - 175ms/epoch - 4ms/step
# Epoch 509/1000
# 41/41 - 0s - loss: 0.4999 - accuracy: 0.9888 - 171ms/epoch - 4ms/step
# Epoch 510/1000
# 41/41 - 0s - loss: 0.4985 - accuracy: 0.9876 - 197ms/epoch - 5ms/step
# Epoch 511/1000
# 41/41 - 0s - loss: 0.4970 - accuracy: 0.9888 - 249ms/epoch - 6ms/step
# Epoch 512/1000
# 41/41 - 0s - loss: 0.4955 - accuracy: 0.9888 - 238ms/epoch - 6ms/step
# Epoch 513/1000
# 41/41 - 0s - loss: 0.4942 - accuracy: 0.9888 - 204ms/epoch - 5ms/step
# Epoch 514/1000
# 41/41 - 0s - loss: 0.4925 - accuracy: 0.9888 - 177ms/epoch - 4ms/step
# Epoch 515/1000
# 41/41 - 0s - loss: 0.4911 - accuracy: 0.9888 - 183ms/epoch - 4ms/step
# Epoch 516/1000
# 41/41 - 0s - loss: 0.4895 - accuracy: 0.9888 - 172ms/epoch - 4ms/step
# Epoch 517/1000
# 41/41 - 0s - loss: 0.4881 - accuracy: 0.9888 - 163ms/epoch - 4ms/step
# Epoch 518/1000
# 41/41 - 0s - loss: 0.4868 - accuracy: 0.9888 - 208ms/epoch - 5ms/step
# Epoch 519/1000
# 41/41 - 0s - loss: 0.4852 - accuracy: 0.9888 - 174ms/epoch - 4ms/step
# Epoch 520/1000
# 41/41 - 0s - loss: 0.4838 - accuracy: 0.9888 - 183ms/epoch - 4ms/step
# Epoch 521/1000
# 41/41 - 0s - loss: 0.4824 - accuracy: 0.9888 - 176ms/epoch - 4ms/step
# Epoch 522/1000
# 41/41 - 0s - loss: 0.4809 - accuracy: 0.9888 - 178ms/epoch - 4ms/step
# Epoch 523/1000
# 41/41 - 0s - loss: 0.4795 - accuracy: 0.9888 - 194ms/epoch - 5ms/step
# Epoch 524/1000
# 41/41 - 0s - loss: 0.4781 - accuracy: 0.9888 - 242ms/epoch - 6ms/step
# Epoch 525/1000
# 41/41 - 0s - loss: 0.4767 - accuracy: 0.9888 - 198ms/epoch - 5ms/step
# Epoch 526/1000
# 41/41 - 0s - loss: 0.4751 - accuracy: 0.9888 - 201ms/epoch - 5ms/step
# Epoch 527/1000
# 41/41 - 0s - loss: 0.4740 - accuracy: 0.9888 - 206ms/epoch - 5ms/step
# Epoch 528/1000
# 41/41 - 0s - loss: 0.4724 - accuracy: 0.9888 - 199ms/epoch - 5ms/step
# Epoch 529/1000
# 41/41 - 0s - loss: 0.4711 - accuracy: 0.9888 - 213ms/epoch - 5ms/step
# Epoch 530/1000
# 41/41 - 0s - loss: 0.4695 - accuracy: 0.9888 - 211ms/epoch - 5ms/step
# Epoch 531/1000
# 41/41 - 0s - loss: 0.4682 - accuracy: 0.9888 - 210ms/epoch - 5ms/step
# Epoch 532/1000
# 41/41 - 0s - loss: 0.4667 - accuracy: 0.9888 - 229ms/epoch - 6ms/step
# Epoch 533/1000
# 41/41 - 0s - loss: 0.4653 - accuracy: 0.9888 - 211ms/epoch - 5ms/step
# Epoch 534/1000
# 41/41 - 0s - loss: 0.4640 - accuracy: 0.9888 - 208ms/epoch - 5ms/step
# Epoch 535/1000
# 41/41 - 0s - loss: 0.4626 - accuracy: 0.9888 - 212ms/epoch - 5ms/step
# Epoch 536/1000
# 41/41 - 0s - loss: 0.4612 - accuracy: 0.9888 - 220ms/epoch - 5ms/step
# Epoch 537/1000
# 41/41 - 0s - loss: 0.4598 - accuracy: 0.9888 - 219ms/epoch - 5ms/step
# Epoch 538/1000
# 41/41 - 0s - loss: 0.4585 - accuracy: 0.9888 - 215ms/epoch - 5ms/step
# Epoch 539/1000
# 41/41 - 0s - loss: 0.4571 - accuracy: 0.9888 - 197ms/epoch - 5ms/step
# Epoch 540/1000
# 41/41 - 0s - loss: 0.4558 - accuracy: 0.9888 - 205ms/epoch - 5ms/step
# Epoch 541/1000
# 41/41 - 0s - loss: 0.4546 - accuracy: 0.9901 - 196ms/epoch - 5ms/step
# Epoch 542/1000
# 41/41 - 0s - loss: 0.4530 - accuracy: 0.9901 - 209ms/epoch - 5ms/step
# Epoch 543/1000
# 41/41 - 0s - loss: 0.4517 - accuracy: 0.9888 - 200ms/epoch - 5ms/step
# Epoch 544/1000
# 41/41 - 0s - loss: 0.4503 - accuracy: 0.9901 - 218ms/epoch - 5ms/step
# Epoch 545/1000
# 41/41 - 0s - loss: 0.4489 - accuracy: 0.9901 - 214ms/epoch - 5ms/step
# Epoch 546/1000
# 41/41 - 0s - loss: 0.4476 - accuracy: 0.9913 - 230ms/epoch - 6ms/step
# Epoch 547/1000
# 41/41 - 0s - loss: 0.4463 - accuracy: 0.9913 - 222ms/epoch - 5ms/step
# Epoch 548/1000
# 41/41 - 0s - loss: 0.4450 - accuracy: 0.9913 - 238ms/epoch - 6ms/step
# Epoch 549/1000
# 41/41 - 0s - loss: 0.4436 - accuracy: 0.9913 - 209ms/epoch - 5ms/step
# Epoch 550/1000
# 41/41 - 0s - loss: 0.4422 - accuracy: 0.9913 - 210ms/epoch - 5ms/step
# Epoch 551/1000
# 41/41 - 0s - loss: 0.4409 - accuracy: 0.9925 - 211ms/epoch - 5ms/step
# Epoch 552/1000
# 41/41 - 0s - loss: 0.4397 - accuracy: 0.9938 - 249ms/epoch - 6ms/step
# Epoch 553/1000
# 41/41 - 0s - loss: 0.4384 - accuracy: 0.9913 - 215ms/epoch - 5ms/step
# Epoch 554/1000
# 41/41 - 0s - loss: 0.4370 - accuracy: 0.9938 - 207ms/epoch - 5ms/step
# Epoch 555/1000
# 41/41 - 0s - loss: 0.4357 - accuracy: 0.9925 - 169ms/epoch - 4ms/step
# Epoch 556/1000
# 41/41 - 0s - loss: 0.4344 - accuracy: 0.9938 - 170ms/epoch - 4ms/step
# Epoch 557/1000
# 41/41 - 0s - loss: 0.4331 - accuracy: 0.9938 - 164ms/epoch - 4ms/step
# Epoch 558/1000
# 41/41 - 0s - loss: 0.4318 - accuracy: 0.9938 - 161ms/epoch - 4ms/step
# Epoch 559/1000
# 41/41 - 0s - loss: 0.4306 - accuracy: 0.9938 - 166ms/epoch - 4ms/step
# Epoch 560/1000
# 41/41 - 0s - loss: 0.4294 - accuracy: 0.9938 - 169ms/epoch - 4ms/step
# Epoch 561/1000
# 41/41 - 0s - loss: 0.4280 - accuracy: 0.9938 - 166ms/epoch - 4ms/step
# Epoch 562/1000
# 41/41 - 0s - loss: 0.4267 - accuracy: 0.9938 - 148ms/epoch - 4ms/step
# Epoch 563/1000
# 41/41 - 0s - loss: 0.4254 - accuracy: 0.9938 - 154ms/epoch - 4ms/step
# Epoch 564/1000
# 41/41 - 0s - loss: 0.4242 - accuracy: 0.9938 - 189ms/epoch - 5ms/step
# Epoch 565/1000
# ...
# Epoch 813/1000
# 41/41 - 0s - loss: 0.2030 - accuracy: 0.9988 - 203ms/epoch - 5ms/step
# Epoch 814/1000
# 41/41 - 0s - loss: 0.2024 - accuracy: 0.9988 - 206ms/epoch - 5ms/step
# Epoch 815/1000
# 41/41 - 0s - loss: 0.2018 - accuracy: 0.9988 - 201ms/epoch - 5ms/step
# Epoch 816/1000
# 41/41 - 0s - loss: 0.2012 - accuracy: 0.9988 - 228ms/epoch - 6ms/step
# Epoch 817/1000
# 41/41 - 0s - loss: 0.2006 - accuracy: 0.9988 - 200ms/epoch - 5ms/step
# Epoch 818/1000
# 41/41 - 0s - loss: 0.2000 - accuracy: 0.9988 - 207ms/epoch - 5ms/step
# Epoch 819/1000
# 41/41 - 0s - loss: 0.1994 - accuracy: 0.9988 - 252ms/epoch - 6ms/step
# Epoch 820/1000
# 41/41 - 0s - loss: 0.1989 - accuracy: 0.9988 - 210ms/epoch - 5ms/step
# Epoch 821/1000
# 41/41 - 0s - loss: 0.1982 - accuracy: 0.9988 - 205ms/epoch - 5ms/step
# Epoch 822/1000
# 41/41 - 0s - loss: 0.1977 - accuracy: 0.9988 - 214ms/epoch - 5ms/step
# Epoch 823/1000
# 41/41 - 0s - loss: 0.1971 - accuracy: 0.9988 - 209ms/epoch - 5ms/step
# Epoch 824/1000
# 41/41 - 0s - loss: 0.1965 - accuracy: 0.9988 - 202ms/epoch - 5ms/step
# Epoch 825/1000
# 41/41 - 0s - loss: 0.1959 - accuracy: 0.9988 - 199ms/epoch - 5ms/step
# Epoch 826/1000
# 41/41 - 0s - loss: 0.1953 - accuracy: 0.9988 - 211ms/epoch - 5ms/step
# Epoch 827/1000
# 41/41 - 0s - loss: 0.1948 - accuracy: 0.9988 - 202ms/epoch - 5ms/step
# Epoch 828/1000
# 41/41 - 0s - loss: 0.1942 - accuracy: 0.9988 - 196ms/epoch - 5ms/step
# Epoch 829/1000
# 41/41 - 0s - loss: 0.1936 - accuracy: 0.9988 - 234ms/epoch - 6ms/step
# Epoch 830/1000
# 41/41 - 0s - loss: 0.1931 - accuracy: 0.9988 - 197ms/epoch - 5ms/step
# Epoch 831/1000
# 41/41 - 0s - loss: 0.1925 - accuracy: 0.9988 - 197ms/epoch - 5ms/step
# Epoch 832/1000
# 41/41 - 0s - loss: 0.1919 - accuracy: 0.9988 - 198ms/epoch - 5ms/step
# Epoch 833/1000
# 41/41 - 0s - loss: 0.1914 - accuracy: 0.9988 - 188ms/epoch - 5ms/step
# Epoch 834/1000
# 41/41 - 0s - loss: 0.1908 - accuracy: 0.9988 - 193ms/epoch - 5ms/step
# Epoch 835/1000
# 41/41 - 0s - loss: 0.1902 - accuracy: 0.9988 - 191ms/epoch - 5ms/step
# Epoch 836/1000
# 41/41 - 0s - loss: 0.1897 - accuracy: 0.9988 - 220ms/epoch - 5ms/step
# Epoch 837/1000
# 41/41 - 0s - loss: 0.1891 - accuracy: 0.9988 - 202ms/epoch - 5ms/step
# Epoch 838/1000
# 41/41 - 0s - loss: 0.1886 - accuracy: 0.9988 - 203ms/epoch - 5ms/step
# Epoch 839/1000
# 41/41 - 0s - loss: 0.1880 - accuracy: 0.9988 - 203ms/epoch - 5ms/step
# Epoch 840/1000
# 41/41 - 0s - loss: 0.1874 - accuracy: 0.9988 - 212ms/epoch - 5ms/step
# Epoch 841/1000
# 41/41 - 0s - loss: 0.1869 - accuracy: 0.9988 - 191ms/epoch - 5ms/step
# Epoch 842/1000
# 41/41 - 0s - loss: 0.1864 - accuracy: 0.9988 - 212ms/epoch - 5ms/step
# Epoch 843/1000
# 41/41 - 0s - loss: 0.1858 - accuracy: 0.9988 - 206ms/epoch - 5ms/step
# Epoch 844/1000
# 41/41 - 0s - loss: 0.1853 - accuracy: 0.9988 - 203ms/epoch - 5ms/step
# Epoch 845/1000
# 41/41 - 0s - loss: 0.1847 - accuracy: 0.9988 - 208ms/epoch - 5ms/step
# Epoch 846/1000
# 41/41 - 0s - loss: 0.1842 - accuracy: 0.9988 - 192ms/epoch - 5ms/step
# Epoch 847/1000
# 41/41 - 0s - loss: 0.1837 - accuracy: 0.9988 - 198ms/epoch - 5ms/step
# Epoch 848/1000
# 41/41 - 0s - loss: 0.1831 - accuracy: 0.9988 - 194ms/epoch - 5ms/step
# Epoch 849/1000
# 41/41 - 0s - loss: 0.1826 - accuracy: 0.9988 - 187ms/epoch - 5ms/step
# Epoch 850/1000
# 41/41 - 0s - loss: 0.1820 - accuracy: 0.9988 - 194ms/epoch - 5ms/step
# Epoch 851/1000
# 41/41 - 0s - loss: 0.1815 - accuracy: 0.9988 - 198ms/epoch - 5ms/step
# Epoch 852/1000
# 41/41 - 0s - loss: 0.1810 - accuracy: 0.9988 - 237ms/epoch - 6ms/step
# Epoch 853/1000
# 41/41 - 0s - loss: 0.1804 - accuracy: 0.9988 - 218ms/epoch - 5ms/step
# Epoch 854/1000
# 41/41 - 0s - loss: 0.1799 - accuracy: 0.9988 - 207ms/epoch - 5ms/step
# Epoch 855/1000
# 41/41 - 0s - loss: 0.1794 - accuracy: 0.9988 - 231ms/epoch - 6ms/step
# Epoch 856/1000
# 41/41 - 0s - loss: 0.1788 - accuracy: 0.9988 - 176ms/epoch - 4ms/step
# Epoch 857/1000
# 41/41 - 0s - loss: 0.1783 - accuracy: 0.9988 - 172ms/epoch - 4ms/step
# Epoch 858/1000
# 41/41 - 0s - loss: 0.1778 - accuracy: 0.9988 - 185ms/epoch - 5ms/step
# Epoch 859/1000
# 41/41 - 0s - loss: 0.1773 - accuracy: 0.9988 - 169ms/epoch - 4ms/step
# Epoch 860/1000
# 41/41 - 0s - loss: 0.1768 - accuracy: 0.9988 - 184ms/epoch - 4ms/step
# Epoch 861/1000
# 41/41 - 0s - loss: 0.1762 - accuracy: 0.9988 - 203ms/epoch - 5ms/step
# Epoch 862/1000
# 41/41 - 0s - loss: 0.1757 - accuracy: 0.9988 - 206ms/epoch - 5ms/step
# Epoch 863/1000
# 41/41 - 0s - loss: 0.1752 - accuracy: 0.9988 - 226ms/epoch - 6ms/step
# Epoch 864/1000
# 41/41 - 0s - loss: 0.1747 - accuracy: 0.9988 - 202ms/epoch - 5ms/step
# Epoch 865/1000
# 41/41 - 0s - loss: 0.1742 - accuracy: 0.9988 - 263ms/epoch - 6ms/step
# Epoch 866/1000
# 41/41 - 0s - loss: 0.1737 - accuracy: 0.9988 - 209ms/epoch - 5ms/step
# Epoch 867/1000
# 41/41 - 0s - loss: 0.1731 - accuracy: 0.9988 - 203ms/epoch - 5ms/step
# Epoch 868/1000
# 41/41 - 0s - loss: 0.1726 - accuracy: 0.9988 - 212ms/epoch - 5ms/step
# Epoch 869/1000
# 41/41 - 0s - loss: 0.1721 - accuracy: 0.9988 - 170ms/epoch - 4ms/step
# Epoch 870/1000
# 41/41 - 0s - loss: 0.1716 - accuracy: 0.9988 - 174ms/epoch - 4ms/step
# Epoch 871/1000
# 41/41 - 0s - loss: 0.1711 - accuracy: 0.9988 - 186ms/epoch - 5ms/step
# Epoch 872/1000
# 41/41 - 0s - loss: 0.1706 - accuracy: 0.9988 - 169ms/epoch - 4ms/step
# Epoch 873/1000
# 41/41 - 0s - loss: 0.1701 - accuracy: 0.9988 - 171ms/epoch - 4ms/step
# Epoch 874/1000
# 41/41 - 0s - loss: 0.1696 - accuracy: 0.9988 - 238ms/epoch - 6ms/step
# Epoch 875/1000
# 41/41 - 0s - loss: 0.1691 - accuracy: 0.9988 - 245ms/epoch - 6ms/step
# Epoch 876/1000
# 41/41 - 0s - loss: 0.1687 - accuracy: 0.9988 - 170ms/epoch - 4ms/step
# Epoch 877/1000
# 41/41 - 0s - loss: 0.1682 - accuracy: 0.9988 - 171ms/epoch - 4ms/step
# Epoch 878/1000
# 41/41 - 0s - loss: 0.1676 - accuracy: 0.9988 - 175ms/epoch - 4ms/step
# Epoch 879/1000
# 41/41 - 0s - loss: 0.1672 - accuracy: 0.9988 - 170ms/epoch - 4ms/step
# Epoch 880/1000
# 41/41 - 0s - loss: 0.1667 - accuracy: 0.9988 - 163ms/epoch - 4ms/step
# Epoch 881/1000
# 41/41 - 0s - loss: 0.1662 - accuracy: 0.9988 - 164ms/epoch - 4ms/step
# Epoch 882/1000
# 41/41 - 0s - loss: 0.1657 - accuracy: 0.9988 - 165ms/epoch - 4ms/step
# Epoch 883/1000
# 41/41 - 0s - loss: 0.1652 - accuracy: 0.9988 - 181ms/epoch - 4ms/step
# Epoch 884/1000
# 41/41 - 0s - loss: 0.1648 - accuracy: 0.9988 - 173ms/epoch - 4ms/step
# Epoch 885/1000
# 41/41 - 0s - loss: 0.1643 - accuracy: 0.9988 - 174ms/epoch - 4ms/step
# Epoch 886/1000
# 41/41 - 0s - loss: 0.1638 - accuracy: 0.9988 - 200ms/epoch - 5ms/step
# Epoch 887/1000
# 41/41 - 0s - loss: 0.1633 - accuracy: 0.9988 - 198ms/epoch - 5ms/step
# Epoch 888/1000
# 41/41 - 0s - loss: 0.1628 - accuracy: 0.9988 - 207ms/epoch - 5ms/step
# Epoch 889/1000
# 41/41 - 0s - loss: 0.1624 - accuracy: 0.9988 - 199ms/epoch - 5ms/step
# Epoch 890/1000
# 41/41 - 0s - loss: 0.1619 - accuracy: 0.9988 - 202ms/epoch - 5ms/step
# Epoch 891/1000
# 41/41 - 0s - loss: 0.1614 - accuracy: 0.9988 - 232ms/epoch - 6ms/step
# Epoch 892/1000
# 41/41 - 0s - loss: 0.1610 - accuracy: 0.9988 - 218ms/epoch - 5ms/step
# Epoch 893/1000
# 41/41 - 0s - loss: 0.1605 - accuracy: 0.9988 - 200ms/epoch - 5ms/step
# Epoch 894/1000
# 41/41 - 0s - loss: 0.1600 - accuracy: 0.9988 - 199ms/epoch - 5ms/step
# Epoch 895/1000
# 41/41 - 0s - loss: 0.1596 - accuracy: 0.9988 - 219ms/epoch - 5ms/step
# Epoch 896/1000
# 41/41 - 0s - loss: 0.1591 - accuracy: 0.9988 - 204ms/epoch - 5ms/step
# Epoch 897/1000
# 41/41 - 0s - loss: 0.1586 - accuracy: 0.9988 - 219ms/epoch - 5ms/step
# Epoch 898/1000
# 41/41 - 0s - loss: 0.1582 - accuracy: 0.9988 - 206ms/epoch - 5ms/step
# Epoch 899/1000
# 41/41 - 0s - loss: 0.1577 - accuracy: 0.9988 - 209ms/epoch - 5ms/step
# Epoch 900/1000
# 41/41 - 0s - loss: 0.1573 - accuracy: 0.9988 - 216ms/epoch - 5ms/step
# Epoch 901/1000
# 41/41 - 0s - loss: 0.1568 - accuracy: 0.9988 - 209ms/epoch - 5ms/step
# Epoch 902/1000
# 41/41 - 0s - loss: 0.1564 - accuracy: 0.9988 - 196ms/epoch - 5ms/step
# Epoch 903/1000
# 41/41 - 0s - loss: 0.1559 - accuracy: 0.9988 - 215ms/epoch - 5ms/step
# Epoch 904/1000
# 41/41 - 0s - loss: 0.1554 - accuracy: 0.9988 - 215ms/epoch - 5ms/step
# Epoch 905/1000
# 41/41 - 0s - loss: 0.1550 - accuracy: 0.9988 - 230ms/epoch - 6ms/step
# Epoch 906/1000
# 41/41 - 0s - loss: 0.1545 - accuracy: 0.9988 - 209ms/epoch - 5ms/step
# Epoch 907/1000
# 41/41 - 0s - loss: 0.1541 - accuracy: 0.9988 - 217ms/epoch - 5ms/step
# Epoch 908/1000
# 41/41 - 0s - loss: 0.1537 - accuracy: 0.9988 - 206ms/epoch - 5ms/step
# Epoch 909/1000
# 41/41 - 0s - loss: 0.1532 - accuracy: 0.9988 - 210ms/epoch - 5ms/step
# Epoch 910/1000
# 41/41 - 0s - loss: 0.1528 - accuracy: 0.9988 - 202ms/epoch - 5ms/step
# Epoch 911/1000
# 41/41 - 0s - loss: 0.1523 - accuracy: 0.9988 - 204ms/epoch - 5ms/step
# Epoch 912/1000
# 41/41 - 0s - loss: 0.1519 - accuracy: 0.9988 - 198ms/epoch - 5ms/step
# Epoch 913/1000
# 41/41 - 0s - loss: 0.1514 - accuracy: 0.9988 - 208ms/epoch - 5ms/step
# Epoch 914/1000
# 41/41 - 0s - loss: 0.1510 - accuracy: 0.9988 - 206ms/epoch - 5ms/step
# Epoch 915/1000
# 41/41 - 0s - loss: 0.1505 - accuracy: 0.9988 - 213ms/epoch - 5ms/step
# Epoch 916/1000
# 41/41 - 0s - loss: 0.1501 - accuracy: 0.9988 - 211ms/epoch - 5ms/step
# Epoch 917/1000
# 41/41 - 0s - loss: 0.1497 - accuracy: 0.9988 - 212ms/epoch - 5ms/step
# Epoch 918/1000
# 41/41 - 0s - loss: 0.1493 - accuracy: 0.9988 - 219ms/epoch - 5ms/step
# Epoch 919/1000
# 41/41 - 0s - loss: 0.1488 - accuracy: 0.9988 - 208ms/epoch - 5ms/step
# Epoch 920/1000
# 41/41 - 0s - loss: 0.1484 - accuracy: 0.9988 - 211ms/epoch - 5ms/step
# Epoch 921/1000
# 41/41 - 0s - loss: 0.1479 - accuracy: 0.9988 - 190ms/epoch - 5ms/step
# Epoch 922/1000
# 41/41 - 0s - loss: 0.1475 - accuracy: 0.9988 - 190ms/epoch - 5ms/step
# Epoch 923/1000
# 41/41 - 0s - loss: 0.1471 - accuracy: 0.9988 - 178ms/epoch - 4ms/step
# Epoch 924/1000
# 41/41 - 0s - loss: 0.1467 - accuracy: 0.9988 - 176ms/epoch - 4ms/step
# Epoch 925/1000
# 41/41 - 0s - loss: 0.1463 - accuracy: 0.9988 - 170ms/epoch - 4ms/step
# Epoch 926/1000
# 41/41 - 0s - loss: 0.1458 - accuracy: 0.9988 - 184ms/epoch - 4ms/step
# Epoch 927/1000
# 41/41 - 0s - loss: 0.1454 - accuracy: 0.9988 - 175ms/epoch - 4ms/step
# Epoch 928/1000
# 41/41 - 0s - loss: 0.1450 - accuracy: 0.9988 - 183ms/epoch - 4ms/step
# Epoch 929/1000
# 41/41 - 0s - loss: 0.1445 - accuracy: 0.9988 - 197ms/epoch - 5ms/step
# Epoch 930/1000
# 41/41 - 0s - loss: 0.1441 - accuracy: 0.9988 - 190ms/epoch - 5ms/step
# Epoch 931/1000
# 41/41 - 0s - loss: 0.1437 - accuracy: 0.9988 - 187ms/epoch - 5ms/step
# Epoch 932/1000
# 41/41 - 0s - loss: 0.1433 - accuracy: 0.9988 - 197ms/epoch - 5ms/step
# Epoch 933/1000
# 41/41 - 0s - loss: 0.1429 - accuracy: 0.9988 - 195ms/epoch - 5ms/step
# Epoch 934/1000
# 41/41 - 0s - loss: 0.1425 - accuracy: 0.9988 - 207ms/epoch - 5ms/step
# Epoch 935/1000
# 41/41 - 0s - loss: 0.1421 - accuracy: 0.9988 - 202ms/epoch - 5ms/step
# Epoch 936/1000
# 41/41 - 0s - loss: 0.1416 - accuracy: 0.9988 - 200ms/epoch - 5ms/step
# Epoch 937/1000
# 41/41 - 0s - loss: 0.1412 - accuracy: 0.9988 - 196ms/epoch - 5ms/step
# Epoch 938/1000
# 41/41 - 0s - loss: 0.1408 - accuracy: 0.9988 - 204ms/epoch - 5ms/step
# Epoch 939/1000
# 41/41 - 0s - loss: 0.1404 - accuracy: 0.9988 - 207ms/epoch - 5ms/step
# Epoch 940/1000
# 41/41 - 0s - loss: 0.1400 - accuracy: 0.9988 - 197ms/epoch - 5ms/step
# Epoch 941/1000
# 41/41 - 0s - loss: 0.1396 - accuracy: 0.9988 - 205ms/epoch - 5ms/step
# Epoch 942/1000
# 41/41 - 0s - loss: 0.1392 - accuracy: 0.9988 - 201ms/epoch - 5ms/step
# Epoch 943/1000
# 41/41 - 0s - loss: 0.1388 - accuracy: 0.9988 - 226ms/epoch - 6ms/step
# Epoch 944/1000
# 41/41 - 0s - loss: 0.1384 - accuracy: 0.9988 - 294ms/epoch - 7ms/step
# Epoch 945/1000
# 41/41 - 0s - loss: 0.1380 - accuracy: 0.9988 - 241ms/epoch - 6ms/step
# Epoch 946/1000
# 41/41 - 0s - loss: 0.1376 - accuracy: 0.9988 - 240ms/epoch - 6ms/step
# Epoch 947/1000
# 41/41 - 0s - loss: 0.1372 - accuracy: 0.9988 - 165ms/epoch - 4ms/step
# Epoch 948/1000
# 41/41 - 0s - loss: 0.1368 - accuracy: 0.9988 - 159ms/epoch - 4ms/step
# Epoch 949/1000
# 41/41 - 0s - loss: 0.1364 - accuracy: 0.9988 - 163ms/epoch - 4ms/step
# Epoch 950/1000
# 41/41 - 0s - loss: 0.1360 - accuracy: 0.9988 - 172ms/epoch - 4ms/step
# Epoch 951/1000
# 41/41 - 0s - loss: 0.1356 - accuracy: 0.9988 - 177ms/epoch - 4ms/step
# Epoch 952/1000
# 41/41 - 0s - loss: 0.1352 - accuracy: 0.9988 - 172ms/epoch - 4ms/step
# Epoch 953/1000
# 41/41 - 0s - loss: 0.1348 - accuracy: 0.9988 - 189ms/epoch - 5ms/step
# Epoch 954/1000
# 41/41 - 0s - loss: 0.1344 - accuracy: 0.9988 - 173ms/epoch - 4ms/step
# Epoch 955/1000
# 41/41 - 0s - loss: 0.1340 - accuracy: 0.9988 - 177ms/epoch - 4ms/step
# Epoch 956/1000
# 41/41 - 0s - loss: 0.1337 - accuracy: 0.9988 - 168ms/epoch - 4ms/step
# Epoch 957/1000
# 41/41 - 0s - loss: 0.1333 - accuracy: 0.9988 - 209ms/epoch - 5ms/step
# Epoch 958/1000
# 41/41 - 0s - loss: 0.1329 - accuracy: 0.9988 - 204ms/epoch - 5ms/step
# Epoch 959/1000
# 41/41 - 0s - loss: 0.1325 - accuracy: 0.9988 - 190ms/epoch - 5ms/step
# Epoch 960/1000
# 41/41 - 0s - loss: 0.1321 - accuracy: 0.9988 - 184ms/epoch - 4ms/step
# Epoch 961/1000
# 41/41 - 0s - loss: 0.1318 - accuracy: 0.9988 - 186ms/epoch - 5ms/step
# Epoch 962/1000
# 41/41 - 0s - loss: 0.1313 - accuracy: 0.9988 - 184ms/epoch - 4ms/step
# Epoch 963/1000
# 41/41 - 0s - loss: 0.1310 - accuracy: 0.9988 - 210ms/epoch - 5ms/step
# Epoch 964/1000
# 41/41 - 0s - loss: 0.1306 - accuracy: 0.9988 - 200ms/epoch - 5ms/step
# Epoch 965/1000
# 41/41 - 0s - loss: 0.1302 - accuracy: 0.9988 - 199ms/epoch - 5ms/step
# Epoch 966/1000
# 41/41 - 0s - loss: 0.1299 - accuracy: 0.9988 - 199ms/epoch - 5ms/step
# Epoch 967/1000
# 41/41 - 0s - loss: 0.1295 - accuracy: 0.9988 - 192ms/epoch - 5ms/step
# Epoch 968/1000
# 41/41 - 0s - loss: 0.1291 - accuracy: 0.9988 - 204ms/epoch - 5ms/step
# Epoch 969/1000
# 41/41 - 0s - loss: 0.1290 - accuracy: 0.9988 - 192ms/epoch - 5ms/step
# Epoch 970/1000
# 41/41 - 0s - loss: 0.1283 - accuracy: 1.0000 - 190ms/epoch - 5ms/step
# Epoch 971/1000
# 41/41 - 0s - loss: 0.1280 - accuracy: 0.9988 - 214ms/epoch - 5ms/step
# Epoch 972/1000
# 41/41 - 0s - loss: 0.1276 - accuracy: 0.9988 - 198ms/epoch - 5ms/step
# Epoch 973/1000
# 41/41 - 0s - loss: 0.1272 - accuracy: 0.9988 - 225ms/epoch - 5ms/step
# Epoch 974/1000
# 41/41 - 0s - loss: 0.1269 - accuracy: 0.9988 - 202ms/epoch - 5ms/step
# Epoch 975/1000
# 41/41 - 0s - loss: 0.1265 - accuracy: 0.9988 - 193ms/epoch - 5ms/step
# Epoch 976/1000
# 41/41 - 0s - loss: 0.1261 - accuracy: 0.9988 - 193ms/epoch - 5ms/step
# Epoch 977/1000
# 41/41 - 0s - loss: 0.1258 - accuracy: 0.9988 - 202ms/epoch - 5ms/step
# Epoch 978/1000
# 41/41 - 0s - loss: 0.1254 - accuracy: 0.9988 - 196ms/epoch - 5ms/step
# Epoch 979/1000
# 41/41 - 0s - loss: 0.1250 - accuracy: 0.9988 - 207ms/epoch - 5ms/step
# Epoch 980/1000
# 41/41 - 0s - loss: 0.1247 - accuracy: 0.9988 - 212ms/epoch - 5ms/step
# Epoch 981/1000
# 41/41 - 0s - loss: 0.1243 - accuracy: 1.0000 - 209ms/epoch - 5ms/step
# Epoch 982/1000
# 41/41 - 0s - loss: 0.1240 - accuracy: 0.9988 - 216ms/epoch - 5ms/step
# Epoch 983/1000
# 41/41 - 0s - loss: 0.1236 - accuracy: 1.0000 - 205ms/epoch - 5ms/step
# Epoch 984/1000
# 41/41 - 0s - loss: 0.1233 - accuracy: 0.9988 - 204ms/epoch - 5ms/step
# Epoch 985/1000
# 41/41 - 0s - loss: 0.1229 - accuracy: 1.0000 - 237ms/epoch - 6ms/step
# Epoch 986/1000
# 41/41 - 0s - loss: 0.1225 - accuracy: 1.0000 - 210ms/epoch - 5ms/step
# Epoch 987/1000
# 41/41 - 0s - loss: 0.1222 - accuracy: 1.0000 - 213ms/epoch - 5ms/step
# Epoch 988/1000
# 41/41 - 0s - loss: 0.1218 - accuracy: 1.0000 - 212ms/epoch - 5ms/step
# Epoch 989/1000
# 41/41 - 0s - loss: 0.1215 - accuracy: 1.0000 - 220ms/epoch - 5ms/step
# Epoch 990/1000
# 41/41 - 0s - loss: 0.1211 - accuracy: 1.0000 - 206ms/epoch - 5ms/step
# Epoch 991/1000
# 41/41 - 0s - loss: 0.1208 - accuracy: 1.0000 - 218ms/epoch - 5ms/step
# Epoch 992/1000
# 41/41 - 0s - loss: 0.1204 - accuracy: 1.0000 - 205ms/epoch - 5ms/step
# Epoch 993/1000
# 41/41 - 0s - loss: 0.1201 - accuracy: 1.0000 - 216ms/epoch - 5ms/step
# Epoch 994/1000
# 41/41 - 0s - loss: 0.1197 - accuracy: 1.0000 - 206ms/epoch - 5ms/step
# Epoch 995/1000
# 41/41 - 0s - loss: 0.1194 - accuracy: 1.0000 - 207ms/epoch - 5ms/step
# Epoch 996/1000
# 41/41 - 0s - loss: 0.1190 - accuracy: 1.0000 - 208ms/epoch - 5ms/step
# Epoch 997/1000
# 41/41 - 0s - loss: 0.1187 - accuracy: 1.0000 - 210ms/epoch - 5ms/step
# Epoch 998/1000
# 41/41 - 0s - loss: 0.1184 - accuracy: 1.0000 - 220ms/epoch - 5ms/step
# Epoch 999/1000
# 41/41 - 0s - loss: 0.1180 - accuracy: 1.0000 - 202ms/epoch - 5ms/step
# Epoch 1000/1000
# 41/41 - 0s - loss: 0.1177 - accuracy: 1.0000 - 210ms/epoch - 5ms/step

# %% [markdown]
# # Validating Model

# %%
result = model.evaluate(testing_data,testing_labels,verbose=1)

# Changing the accuracy into a percentage
testing_acc = result[1]*100
# Printing the accuracy
print('Test Accuracy - ', testing_acc,'%')
print(dict(zip(model.metrics_names, result)))

predictions = model(testing_data, training=False)
print('Looping through the testing data and checking results:')
for i, (expect, predict) in enumerate(zip(testing_labels.numpy() , predictions.numpy())):
    print('{:5}/{:<5}: True: {:25} Predicted: {:25} | {:^7} | Choice probability = {:.1f}%'.format(i+1, testing_data.shape[0], label_dict[expect[0]], label_dict[predict.argmax()], ['Wrong', 'Correct'][predict.argmax() == expect[0]],  predict.max()*100))
# Out:
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1564 - accuracy: 0.9901
# Test Accuracy -  99.00990128517151 %
# {'loss': 0.15635132789611816, 'accuracy': 0.9900990128517151}
# Looping through the testing data and checking results:
#     1/202  : True: Bahrain Grand Prix        Predicted: Bahrain Grand Prix        | Correct | Choice probability = 90.8%
#     2/202  : True: Canadian Grand Prix       Predicted: Canadian Grand Prix       | Correct | Choice probability = 85.9%
#     3/202  : True: Dutch Grand Prix          Predicted: Dutch Grand Prix          | Correct | Choice probability = 96.4%
#     4/202  : True: Belgian Grand Prix        Predicted: Belgian Grand Prix        | Correct | Choice probability = 92.5%
#     5/202  : True: Spanish Grand Prix        Predicted: Spanish Grand Prix        | Correct | Choice probability = 91.0%
#     6/202  : True: Canadian Grand Prix       Predicted: Canadian Grand Prix       | Correct | Choice probability = 86.4%
#     7/202  : True: British Grand Prix        Predicted: British Grand Prix        | Correct | Choice probability = 90.6%
#     8/202  : True: São Paulo Grand Prix      Predicted: São Paulo Grand Prix      | Correct | Choice probability = 89.5%
#     9/202  : True: Spanish Grand Prix        Predicted: Spanish Grand Prix        | Correct | Choice probability = 91.1%
#    10/202  : True: São Paulo Grand Prix      Predicted: São Paulo Grand Prix      | Correct | Choice probability = 89.5%
#    11/202  : True: Canadian Grand Prix       Predicted: Canadian Grand Prix       | Correct | Choice probability = 85.7%
#    12/202  : True: Abu Dhabi Grand Prix      Predicted: Abu Dhabi Grand Prix      | Correct | Choice probability = 92.9%
#    13/202  : True: Abu Dhabi Grand Prix      Predicted: Abu Dhabi Grand Prix      | Correct | Choice probability = 92.8%
#    14/202  : True: Abu Dhabi Grand Prix      Predicted: Abu Dhabi Grand Prix      | Correct | Choice probability = 92.9%
#    15/202  : True: Emilia Romagna Grand Prix Predicted: Emilia Romagna Grand Prix | Correct | Choice probability = 89.1%
#    16/202  : True: Azerbaijan Grand Prix     Predicted: Azerbaijan Grand Prix     | Correct | Choice probability = 86.9%
#    17/202  : True: Italian Grand Prix        Predicted: Italian Grand Prix        | Correct | Choice probability = 89.5%
#    18/202  : True: Austrian Grand Prix       Predicted: Austrian Grand Prix       | Correct | Choice probability = 93.5%
#    19/202  : True: Hungarian Grand Prix      Predicted: Hungarian Grand Prix      | Correct | Choice probability = 94.5%
#    20/202  : True: Austrian Grand Prix       Predicted: Austrian Grand Prix       | Correct | Choice probability = 93.6%
#    21/202  : True: Bahrain Grand Prix        Predicted: Bahrain Grand Prix        | Correct | Choice probability = 90.1%
#    22/202  : True: São Paulo Grand Prix      Predicted: São Paulo Grand Prix      | Correct | Choice probability = 89.2%
#    23/202  : True: Spanish Grand Prix        Predicted: Spanish Grand Prix        | Correct | Choice probability = 91.0%
#    24/202  : True: Mexico City Grand Prix    Predicted: Mexico City Grand Prix    | Correct | Choice probability = 95.0%
#    25/202  : True: Canadian Grand Prix       Predicted: Canadian Grand Prix       | Correct | Choice probability = 86.5%
#    26/202  : True: São Paulo Grand Prix      Predicted: São Paulo Grand Prix      | Correct | Choice probability = 89.5%
#    27/202  : True: Austrian Grand Prix       Predicted: Austrian Grand Prix       | Correct | Choice probability = 91.2%
#    28/202  : True: Saudi Arabian Grand Prix  Predicted: Saudi Arabian Grand Prix  | Correct | Choice probability = 86.6%
#    29/202  : True: Hungarian Grand Prix      Predicted: Hungarian Grand Prix      | Correct | Choice probability = 94.4%
#    30/202  : True: Hungarian Grand Prix      Predicted: Hungarian Grand Prix      | Correct | Choice probability = 94.4%
#    31/202  : True: United States Grand Prix  Predicted: United States Grand Prix  | Correct | Choice probability = 92.8%
#    32/202  : True: Australian Grand Prix     Predicted: Australian Grand Prix     | Correct | Choice probability = 81.4%
#    33/202  : True: Saudi Arabian Grand Prix  Predicted: Saudi Arabian Grand Prix  | Correct | Choice probability = 86.3%
#    34/202  : True: Abu Dhabi Grand Prix      Predicted: Abu Dhabi Grand Prix      | Correct | Choice probability = 92.9%
#    35/202  : True: Monaco Grand Prix         Predicted: Monaco Grand Prix         | Correct | Choice probability = 67.3%
#    36/202  : True: Monaco Grand Prix         Predicted: Monaco Grand Prix         | Correct | Choice probability = 68.7%
#    37/202  : True: Singapore Grand Prix      Predicted: Singapore Grand Prix      | Correct | Choice probability = 64.1%
#    38/202  : True: Canadian Grand Prix       Predicted: Canadian Grand Prix       | Correct | Choice probability = 85.9%
#    39/202  : True: Mexico City Grand Prix    Predicted: Mexico City Grand Prix    | Correct | Choice probability = 95.0%
#    40/202  : True: Singapore Grand Prix      Predicted: Singapore Grand Prix      | Correct | Choice probability = 72.0%
#    41/202  : True: Abu Dhabi Grand Prix      Predicted: Abu Dhabi Grand Prix      | Correct | Choice probability = 92.9%
#    42/202  : True: United States Grand Prix  Predicted: United States Grand Prix  | Correct | Choice probability = 92.7%
#    43/202  : True: Abu Dhabi Grand Prix      Predicted: Abu Dhabi Grand Prix      | Correct | Choice probability = 92.8%
#    44/202  : True: United States Grand Prix  Predicted: United States Grand Prix  | Correct | Choice probability = 92.9%
#    45/202  : True: Austrian Grand Prix       Predicted: Austrian Grand Prix       | Correct | Choice probability = 93.7%
#    46/202  : True: Belgian Grand Prix        Predicted: Belgian Grand Prix        | Correct | Choice probability = 92.7%
#    47/202  : True: Miami Grand Prix          Predicted: Miami Grand Prix          | Correct | Choice probability = 87.8%
#    48/202  : True: Saudi Arabian Grand Prix  Predicted: Saudi Arabian Grand Prix  | Correct | Choice probability = 86.5%
#    49/202  : True: São Paulo Grand Prix      Predicted: São Paulo Grand Prix      | Correct | Choice probability = 89.5%
#    50/202  : True: Hungarian Grand Prix      Predicted: Hungarian Grand Prix      | Correct | Choice probability = 94.3%
#    51/202  : True: Emilia Romagna Grand Prix Predicted: Emilia Romagna Grand Prix | Correct | Choice probability = 89.5%
#    52/202  : True: British Grand Prix        Predicted: British Grand Prix        | Correct | Choice probability = 90.5%
#    53/202  : True: Austrian Grand Prix       Predicted: Austrian Grand Prix       | Correct | Choice probability = 93.5%
#    54/202  : True: Australian Grand Prix     Predicted: Australian Grand Prix     | Correct | Choice probability = 81.4%
#    55/202  : True: United States Grand Prix  Predicted: United States Grand Prix  | Correct | Choice probability = 92.7%
#    56/202  : True: Emilia Romagna Grand Prix Predicted: Emilia Romagna Grand Prix | Correct | Choice probability = 89.6%
#    57/202  : True: Belgian Grand Prix        Predicted: Belgian Grand Prix        | Correct | Choice probability = 92.6%
#    58/202  : True: Miami Grand Prix          Predicted: Miami Grand Prix          | Correct | Choice probability = 87.4%
#    59/202  : True: Dutch Grand Prix          Predicted: Dutch Grand Prix          | Correct | Choice probability = 96.4%
#    60/202  : True: Austrian Grand Prix       Predicted: Austrian Grand Prix       | Correct | Choice probability = 93.7%
#    61/202  : True: Abu Dhabi Grand Prix      Predicted: Abu Dhabi Grand Prix      | Correct | Choice probability = 92.9%
#    62/202  : True: United States Grand Prix  Predicted: United States Grand Prix  | Correct | Choice probability = 92.7%
#    63/202  : True: Mexico City Grand Prix    Predicted: Mexico City Grand Prix    | Correct | Choice probability = 94.7%
#    64/202  : True: Canadian Grand Prix       Predicted: Canadian Grand Prix       | Correct | Choice probability = 86.5%
#    65/202  : True: Mexico City Grand Prix    Predicted: Mexico City Grand Prix    | Correct | Choice probability = 95.1%
#    66/202  : True: Australian Grand Prix     Predicted: Australian Grand Prix     | Correct | Choice probability = 81.2%
#    67/202  : True: British Grand Prix        Predicted: British Grand Prix        | Correct | Choice probability = 90.6%
#    68/202  : True: Monaco Grand Prix         Predicted: Monaco Grand Prix         | Correct | Choice probability = 53.4%
#    69/202  : True: Mexico City Grand Prix    Predicted: Mexico City Grand Prix    | Correct | Choice probability = 95.1%
#    70/202  : True: Mexico City Grand Prix    Predicted: Mexico City Grand Prix    | Correct | Choice probability = 95.1%
#    71/202  : True: Saudi Arabian Grand Prix  Predicted: Saudi Arabian Grand Prix  | Correct | Choice probability = 86.6%
#    72/202  : True: Bahrain Grand Prix        Predicted: Bahrain Grand Prix        | Correct | Choice probability = 90.7%
#    73/202  : True: Belgian Grand Prix        Predicted: Belgian Grand Prix        | Correct | Choice probability = 92.7%
#    74/202  : True: Austrian Grand Prix       Predicted: Austrian Grand Prix       | Correct | Choice probability = 93.4%
#    75/202  : True: Singapore Grand Prix      Predicted: Singapore Grand Prix      | Correct | Choice probability = 71.0%
#    76/202  : True: Italian Grand Prix        Predicted: Italian Grand Prix        | Correct | Choice probability = 89.5%
#    77/202  : True: Singapore Grand Prix      Predicted: Singapore Grand Prix      | Correct | Choice probability = 71.4%
#    78/202  : True: Hungarian Grand Prix      Predicted: Hungarian Grand Prix      | Correct | Choice probability = 94.5%
#    79/202  : True: Mexico City Grand Prix    Predicted: Mexico City Grand Prix    | Correct | Choice probability = 94.9%
#    80/202  : True: Emilia Romagna Grand Prix Predicted: Emilia Romagna Grand Prix | Correct | Choice probability = 89.6%
#    81/202  : True: Saudi Arabian Grand Prix  Predicted: Saudi Arabian Grand Prix  | Correct | Choice probability = 85.7%
#    82/202  : True: Miami Grand Prix          Predicted: Miami Grand Prix          | Correct | Choice probability = 87.7%
#    83/202  : True: French Grand Prix         Predicted: French Grand Prix         | Correct | Choice probability = 91.8%
#    84/202  : True: Bahrain Grand Prix        Predicted: Bahrain Grand Prix        | Correct | Choice probability = 90.7%
#    85/202  : True: Singapore Grand Prix      Predicted: Singapore Grand Prix      | Correct | Choice probability = 72.3%
#    86/202  : True: Belgian Grand Prix        Predicted: Belgian Grand Prix        | Correct | Choice probability = 92.6%
#    87/202  : True: Belgian Grand Prix        Predicted: Belgian Grand Prix        | Correct | Choice probability = 92.6%
#    88/202  : True: Italian Grand Prix        Predicted: Italian Grand Prix        | Correct | Choice probability = 89.5%
#    89/202  : True: Singapore Grand Prix      Predicted: Singapore Grand Prix      | Correct | Choice probability = 52.0%
#    90/202  : True: Miami Grand Prix          Predicted: Miami Grand Prix          | Correct | Choice probability = 87.8%
#    91/202  : True: Belgian Grand Prix        Predicted: Belgian Grand Prix        | Correct | Choice probability = 92.6%
#    92/202  : True: Singapore Grand Prix      Predicted: Singapore Grand Prix      | Correct | Choice probability = 72.3%
#    93/202  : True: United States Grand Prix  Predicted: United States Grand Prix  | Correct | Choice probability = 92.7%
#    94/202  : True: São Paulo Grand Prix      Predicted: São Paulo Grand Prix      | Correct | Choice probability = 89.0%
#    95/202  : True: United States Grand Prix  Predicted: United States Grand Prix  | Correct | Choice probability = 92.8%
#    96/202  : True: Australian Grand Prix     Predicted: Australian Grand Prix     | Correct | Choice probability = 81.2%
#    97/202  : True: Canadian Grand Prix       Predicted: Canadian Grand Prix       | Correct | Choice probability = 86.3%
#    98/202  : True: Hungarian Grand Prix      Predicted: Hungarian Grand Prix      | Correct | Choice probability = 94.3%
#    99/202  : True: Australian Grand Prix     Predicted: Australian Grand Prix     | Correct | Choice probability = 81.4%
#   100/202  : True: Singapore Grand Prix      Predicted: Singapore Grand Prix      | Correct | Choice probability = 72.0%
#   101/202  : True: Emilia Romagna Grand Prix Predicted: Emilia Romagna Grand Prix | Correct | Choice probability = 89.2%
#   102/202  : True: Monaco Grand Prix         Predicted: Monaco Grand Prix         | Correct | Choice probability = 71.7%
#   103/202  : True: United States Grand Prix  Predicted: United States Grand Prix  | Correct | Choice probability = 92.9%
#   104/202  : True: Bahrain Grand Prix        Predicted: Bahrain Grand Prix        | Correct | Choice probability = 90.1%
#   105/202  : True: São Paulo Grand Prix      Predicted: São Paulo Grand Prix      | Correct | Choice probability = 89.5%
#   106/202  : True: Azerbaijan Grand Prix     Predicted: Azerbaijan Grand Prix     | Correct | Choice probability = 87.0%
#   107/202  : True: British Grand Prix        Predicted: British Grand Prix        | Correct | Choice probability = 90.4%
#   108/202  : True: Dutch Grand Prix          Predicted: Dutch Grand Prix          | Correct | Choice probability = 96.4%
#   109/202  : True: Mexico City Grand Prix    Predicted: Mexico City Grand Prix    | Correct | Choice probability = 94.9%
#   110/202  : True: Mexico City Grand Prix    Predicted: Mexico City Grand Prix    | Correct | Choice probability = 94.9%
#   111/202  : True: Japanese Grand Prix       Predicted: Japanese Grand Prix       | Correct | Choice probability = 65.8%
#   112/202  : True: Hungarian Grand Prix      Predicted: Hungarian Grand Prix      | Correct | Choice probability = 94.4%
#   113/202  : True: Bahrain Grand Prix        Predicted: Bahrain Grand Prix        | Correct | Choice probability = 90.8%
#   114/202  : True: Mexico City Grand Prix    Predicted: Mexico City Grand Prix    | Correct | Choice probability = 95.0%
#   115/202  : True: Mexico City Grand Prix    Predicted: Mexico City Grand Prix    | Correct | Choice probability = 94.9%
#   116/202  : True: Dutch Grand Prix          Predicted: Dutch Grand Prix          | Correct | Choice probability = 96.0%
#   117/202  : True: Bahrain Grand Prix        Predicted: Bahrain Grand Prix        | Correct | Choice probability = 90.8%
#   118/202  : True: Azerbaijan Grand Prix     Predicted: Azerbaijan Grand Prix     | Correct | Choice probability = 87.0%
#   119/202  : True: Spanish Grand Prix        Predicted: Spanish Grand Prix        | Correct | Choice probability = 91.0%
#   120/202  : True: Spanish Grand Prix        Predicted: Spanish Grand Prix        | Correct | Choice probability = 91.0%
#   121/202  : True: Bahrain Grand Prix        Predicted: Bahrain Grand Prix        | Correct | Choice probability = 90.7%
#   122/202  : True: Azerbaijan Grand Prix     Predicted: Azerbaijan Grand Prix     | Correct | Choice probability = 87.1%
#   123/202  : True: Mexico City Grand Prix    Predicted: Mexico City Grand Prix    | Correct | Choice probability = 95.0%
#   124/202  : True: Emilia Romagna Grand Prix Predicted: Emilia Romagna Grand Prix | Correct | Choice probability = 89.5%
#   125/202  : True: Canadian Grand Prix       Predicted: Canadian Grand Prix       | Correct | Choice probability = 86.4%
#   126/202  : True: Dutch Grand Prix          Predicted: Dutch Grand Prix          | Correct | Choice probability = 96.4%
#   127/202  : True: Monaco Grand Prix         Predicted: São Paulo Grand Prix      |  Wrong  | Choice probability = 36.6%
#   128/202  : True: Abu Dhabi Grand Prix      Predicted: Abu Dhabi Grand Prix      | Correct | Choice probability = 92.9%
#   129/202  : True: Japanese Grand Prix       Predicted: Japanese Grand Prix       | Correct | Choice probability = 65.7%
#   130/202  : True: Hungarian Grand Prix      Predicted: Hungarian Grand Prix      | Correct | Choice probability = 94.5%
#   131/202  : True: British Grand Prix        Predicted: British Grand Prix        | Correct | Choice probability = 90.6%
#   132/202  : True: São Paulo Grand Prix      Predicted: São Paulo Grand Prix      | Correct | Choice probability = 89.1%
#   133/202  : True: Belgian Grand Prix        Predicted: Belgian Grand Prix        | Correct | Choice probability = 92.6%
#   134/202  : True: Miami Grand Prix          Predicted: Miami Grand Prix          | Correct | Choice probability = 87.6%
#   135/202  : True: São Paulo Grand Prix      Predicted: São Paulo Grand Prix      | Correct | Choice probability = 89.3%
#   136/202  : True: Belgian Grand Prix        Predicted: Belgian Grand Prix        | Correct | Choice probability = 92.6%
#   137/202  : True: Azerbaijan Grand Prix     Predicted: Azerbaijan Grand Prix     | Correct | Choice probability = 86.7%
#   138/202  : True: British Grand Prix        Predicted: British Grand Prix        | Correct | Choice probability = 90.5%
#   139/202  : True: Bahrain Grand Prix        Predicted: Bahrain Grand Prix        | Correct | Choice probability = 90.7%
#   140/202  : True: Austrian Grand Prix       Predicted: Austrian Grand Prix       | Correct | Choice probability = 93.7%
#   141/202  : True: Canadian Grand Prix       Predicted: Canadian Grand Prix       | Correct | Choice probability = 86.1%
#   142/202  : True: United States Grand Prix  Predicted: United States Grand Prix  | Correct | Choice probability = 92.5%
#   143/202  : True: Australian Grand Prix     Predicted: Australian Grand Prix     | Correct | Choice probability = 80.9%
#   144/202  : True: United States Grand Prix  Predicted: United States Grand Prix  | Correct | Choice probability = 92.7%
#   145/202  : True: Emilia Romagna Grand Prix Predicted: Emilia Romagna Grand Prix | Correct | Choice probability = 89.6%
#   146/202  : True: British Grand Prix        Predicted: British Grand Prix        | Correct | Choice probability = 90.0%
#   147/202  : True: Canadian Grand Prix       Predicted: Canadian Grand Prix       | Correct | Choice probability = 86.4%
#   148/202  : True: United States Grand Prix  Predicted: United States Grand Prix  | Correct | Choice probability = 92.7%
#   149/202  : True: Monaco Grand Prix         Predicted: Monaco Grand Prix         | Correct | Choice probability = 71.5%
#   150/202  : True: Austrian Grand Prix       Predicted: Austrian Grand Prix       | Correct | Choice probability = 93.7%
#   151/202  : True: Austrian Grand Prix       Predicted: Austrian Grand Prix       | Correct | Choice probability = 93.3%
#   152/202  : True: Japanese Grand Prix       Predicted: Japanese Grand Prix       | Correct | Choice probability = 66.5%
#   153/202  : True: Belgian Grand Prix        Predicted: Belgian Grand Prix        | Correct | Choice probability = 92.6%
#   154/202  : True: United States Grand Prix  Predicted: United States Grand Prix  | Correct | Choice probability = 92.8%
#   155/202  : True: Italian Grand Prix        Predicted: Italian Grand Prix        | Correct | Choice probability = 89.5%
#   156/202  : True: Bahrain Grand Prix        Predicted: Bahrain Grand Prix        | Correct | Choice probability = 90.3%
#   157/202  : True: Italian Grand Prix        Predicted: Italian Grand Prix        | Correct | Choice probability = 89.5%
#   158/202  : True: Italian Grand Prix        Predicted: Italian Grand Prix        | Correct | Choice probability = 89.5%
#   159/202  : True: Emilia Romagna Grand Prix Predicted: Emilia Romagna Grand Prix | Correct | Choice probability = 89.4%
#   160/202  : True: São Paulo Grand Prix      Predicted: São Paulo Grand Prix      | Correct | Choice probability = 89.4%
#   161/202  : True: Australian Grand Prix     Predicted: Australian Grand Prix     | Correct | Choice probability = 81.0%
#   162/202  : True: Spanish Grand Prix        Predicted: Spanish Grand Prix        | Correct | Choice probability = 91.0%
#   163/202  : True: Abu Dhabi Grand Prix      Predicted: Abu Dhabi Grand Prix      | Correct | Choice probability = 92.9%
#   164/202  : True: Japanese Grand Prix       Predicted: Japanese Grand Prix       | Correct | Choice probability = 63.0%
#   165/202  : True: Emilia Romagna Grand Prix Predicted: Emilia Romagna Grand Prix | Correct | Choice probability = 89.3%
#   166/202  : True: Azerbaijan Grand Prix     Predicted: Azerbaijan Grand Prix     | Correct | Choice probability = 87.0%
#   167/202  : True: French Grand Prix         Predicted: French Grand Prix         | Correct | Choice probability = 91.7%
#   168/202  : True: Australian Grand Prix     Predicted: Australian Grand Prix     | Correct | Choice probability = 81.1%
#   169/202  : True: Canadian Grand Prix       Predicted: Canadian Grand Prix       | Correct | Choice probability = 86.2%
#   170/202  : True: French Grand Prix         Predicted: French Grand Prix         | Correct | Choice probability = 91.7%
#   171/202  : True: Dutch Grand Prix          Predicted: Dutch Grand Prix          | Correct | Choice probability = 96.0%
#   172/202  : True: Emilia Romagna Grand Prix Predicted: Emilia Romagna Grand Prix | Correct | Choice probability = 89.6%
#   173/202  : True: Hungarian Grand Prix      Predicted: Hungarian Grand Prix      | Correct | Choice probability = 94.5%
#   174/202  : True: Abu Dhabi Grand Prix      Predicted: Abu Dhabi Grand Prix      | Correct | Choice probability = 92.4%
#   175/202  : True: Dutch Grand Prix          Predicted: Dutch Grand Prix          | Correct | Choice probability = 96.3%
#   176/202  : True: Miami Grand Prix          Predicted: Miami Grand Prix          | Correct | Choice probability = 87.8%
#   177/202  : True: Miami Grand Prix          Predicted: Miami Grand Prix          | Correct | Choice probability = 87.5%
#   178/202  : True: Dutch Grand Prix          Predicted: Dutch Grand Prix          | Correct | Choice probability = 96.5%
#   179/202  : True: Austrian Grand Prix       Predicted: Austrian Grand Prix       | Correct | Choice probability = 93.7%
#   180/202  : True: Australian Grand Prix     Predicted: Australian Grand Prix     | Correct | Choice probability = 81.3%
#   181/202  : True: Dutch Grand Prix          Predicted: Dutch Grand Prix          | Correct | Choice probability = 96.0%
#   182/202  : True: Abu Dhabi Grand Prix      Predicted: Abu Dhabi Grand Prix      | Correct | Choice probability = 92.9%
#   183/202  : True: Spanish Grand Prix        Predicted: Spanish Grand Prix        | Correct | Choice probability = 91.0%
#   184/202  : True: Azerbaijan Grand Prix     Predicted: Azerbaijan Grand Prix     | Correct | Choice probability = 87.0%
#   185/202  : True: Azerbaijan Grand Prix     Predicted: Azerbaijan Grand Prix     | Correct | Choice probability = 86.5%
#   186/202  : True: Mexico City Grand Prix    Predicted: Mexico City Grand Prix    | Correct | Choice probability = 95.0%
#   187/202  : True: Hungarian Grand Prix      Predicted: Hungarian Grand Prix      | Correct | Choice probability = 94.5%
#   188/202  : True: Japanese Grand Prix       Predicted: Japanese Grand Prix       | Correct | Choice probability = 66.7%
#   189/202  : True: Italian Grand Prix        Predicted: Italian Grand Prix        | Correct | Choice probability = 89.5%
#   190/202  : True: Japanese Grand Prix       Predicted: Mexico City Grand Prix    |  Wrong  | Choice probability = 32.4%
#   191/202  : True: Saudi Arabian Grand Prix  Predicted: Saudi Arabian Grand Prix  | Correct | Choice probability = 86.6%
#   192/202  : True: Hungarian Grand Prix      Predicted: Hungarian Grand Prix      | Correct | Choice probability = 94.5%
#   193/202  : True: Belgian Grand Prix        Predicted: Belgian Grand Prix        | Correct | Choice probability = 92.5%
#   194/202  : True: Austrian Grand Prix       Predicted: Austrian Grand Prix       | Correct | Choice probability = 93.6%
#   195/202  : True: Azerbaijan Grand Prix     Predicted: Azerbaijan Grand Prix     | Correct | Choice probability = 87.0%
#   196/202  : True: Azerbaijan Grand Prix     Predicted: Azerbaijan Grand Prix     | Correct | Choice probability = 87.2%
#   197/202  : True: Austrian Grand Prix       Predicted: Austrian Grand Prix       | Correct | Choice probability = 93.6%
#   198/202  : True: Monaco Grand Prix         Predicted: Monaco Grand Prix         | Correct | Choice probability = 75.5%
#   199/202  : True: British Grand Prix        Predicted: British Grand Prix        | Correct | Choice probability = 90.6%
#   200/202  : True: Hungarian Grand Prix      Predicted: Hungarian Grand Prix      | Correct | Choice probability = 94.5%
#   201/202  : True: Canadian Grand Prix       Predicted: Canadian Grand Prix       | Correct | Choice probability = 86.4%
#   202/202  : True: Italian Grand Prix        Predicted: Italian Grand Prix        | Correct | Choice probability = 89.5%

# %% [markdown]
# # Conclusions
#
# Using machine learning with *keras* and *tensorflow* we have been able to create a model capable of distinguishing tracks based solely upon the speed trace of Formula 1 drivers!
#
# # See Also
#
# * I am trying to apply this same framework to distinguish between driver's specific driving patterns.  The differences between drivers is far more subtle than the differences between tracks, so this has been a challenge.  Please check that out if you wish to see more: [f1_djsouthall/ml/guess_driver_from_telem.ipynb](https://github.com/djsouthall/f1_djsouthall/blob/main/ml/guess_driver_from_telem.ipynb)
#
# * I have also been playing with the fastf1 tool to scrape other forms of F1 race data and store this data into SQL databases.  To see that work please look at the work found in [f1_djsouthall/sql/make_tables.py](https://github.com/djsouthall/f1_djsouthall/tree/main/sql/make_tables.py) (for SQL table creation) and [f1_djsouthall/sql/example_sql_analysis.py](https://github.com/djsouthall/f1_djsouthall/tree/main/sql/example_sql_analysis.py) (for example analysis performed using that database).
